# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Set Trial Name

# %%
TRIAL_NAME = "13_remove_tarenc"

import datetime
import pytz
NOW = datetime.datetime.now(pytz.timezone('Asia/Tokyo')).strftime('%Y%m%d%H%M%S')

# %% [markdown]
# # Load yaml

# %%
import yaml
CONFIG_DIR = '../config'
with open(f'{CONFIG_DIR}/run000.yml') as file:
    cfg = yaml.safe_load(file)

import sys
sys.path.append(cfg['SRC_DIR'])
cfg['run_name'] = TRIAL_NAME

# %% [markdown]
# # fix seed

# %%
from util import seed_everything
seed_everything(seed=33, use_torch=False)

# %% [markdown]
# # Make Output Folder

# %%
import os
OUTPUT_DIR = f'../../output/{NOW}_{TRIAL_NAME}'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# # Load Model

# %%
import pandas as pd
import numpy as np

sub = pd.read_csv('../../data/atmacup10__sample_submission.csv')
color = pd.read_csv('../../data/color.csv')
historical_person = pd.read_csv('../../data/historical_person.csv')
maker = pd.read_csv('../../data/maker.csv')
material = pd.read_csv('../../data/material.csv')
object_collection = pd.read_csv('../../data/object_collection.csv')
palette = pd.read_csv('../../data/palette.csv')
principal_maker_occupation = pd.read_csv('../../data/principal_maker_occupation.csv')
principal_maker = pd.read_csv('../../data/principal_maker.csv')
production_place = pd.read_csv('../../data/production_place.csv')
technique = pd.read_csv('../../data/technique.csv')
test = pd.read_csv('../../data/test.csv')
test[cfg['target']] = np.nan
train = pd.read_csv('../../data/train.csv')

# %%
train.head(2)
# Out:
#               object_id         art_series_id                  title  \
# 0  0011d6be41612ec9eae3  93c092ba70beab248f31  The Avenue of Birches
# 1  0012765f7a97ccc3e9e9  95c14fb11c54281ad7e0        Struik in bloei
#
#   description                                         long_title  \
# 0         NaN   The Avenue of Birches, Jan Hackaert, 1660 - 1685
# 1         NaN  Struik in bloei, Richard Tepe (attributed to),...
#
#   principal_maker principal_or_first_maker  \
# 0    Jan Hackaert             Jan Hackaert
# 1    Richard Tepe             Richard Tepe
#
#                                  sub_title    copyright_holder  \
# 0  h 66.5cm × w 53.7cm × t 2.5cm × d 4.7cm                 NaN
# 1                        h 165mm × w 223mm  erven Richard Tepe
#
#               more_title acquisition_method     acquisition_date  \
# 0  The Avenue of Birches           purchase  1808-01-01T00:00:00
# 1        Struik in bloei           purchase  2000-01-01T00:00:00
#
#   acquisition_credit_line dating_presenting_date  dating_sorting_date  \
# 0                     NaN            1660 - 1685               1660.0
# 1                     NaN      c. 1900 - c. 1930               1900.0
#
#    dating_period  dating_year_early  dating_year_late  likes
# 0             17             1660.0            1685.0     48
# 1             19             1900.0            1930.0      2

# %%
test.head(2)
# Out:
#               object_id         art_series_id  \
# 0  000405d9a5e3f49fc49d  a2aabd3cc8859f4260ad
# 1  001020bd00b149970f78  5d6a286cc3ab64c2c043
#
#                                                title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#                                          description  \
# 0                                                NaN
# 1  Portret van Philip Ernst (1585-1629), graaf va...
#
#                                           long_title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#               principal_maker    principal_or_first_maker  \
# 0          Bernardus Bruining          Bernardus Bruining
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn
#
#              sub_title copyright_holder  \
# 0    h 167mm × w 108mm              NaN
# 1  h 29.7cm × w 24.1cm              NaN
#
#                                           more_title    acquisition_method  \
# 0  Twee personen voor de Duizendjarige den te Wol...              transfer
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...  nationalization 1795
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1994-01-01T00:00:00                     NaN            1850 - 1900
# 1  1798-09-01T00:00:00                     NaN      c. 1609 - c. 1633
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1850.0             19             1850.0            1900.0
# 1               1609.0             17             1609.0            1633.0
#
#    likes
# 0    NaN
# 1    NaN

# %%
del_non_overlapping_list = [
    # 'object_id',
    'art_series_id',
    #'title',
    #'description',
    #'long_title',
    'principal_maker',
    'principal_or_first_maker',
    #'sub_title',
    'copyright_holder',
    #'more_title',
    'acquisition_method',
    # 'acquisition_date',
    # 'acquisition_credit_line',
    # 'dating_presenting_date',
    # 'dating_sorting_date',
    'dating_period',
    # 'dating_year_early',
    # 'dating_year_late'
]

from util import replace_non_overlap_val_to_missing
train, test = replace_non_overlap_val_to_missing(train,test,columns=del_non_overlapping_list)

# %%
train.head(2)
# Out:
#               object_id art_series_id                  title description  \
# 0  0011d6be41612ec9eae3         other  The Avenue of Birches         NaN
# 1  0012765f7a97ccc3e9e9         other        Struik in bloei         NaN
#
#                                           long_title principal_maker  \
# 0   The Avenue of Birches, Jan Hackaert, 1660 - 1685    Jan Hackaert
# 1  Struik in bloei, Richard Tepe (attributed to),...    Richard Tepe
#
#   principal_or_first_maker                                sub_title  \
# 0             Jan Hackaert  h 66.5cm × w 53.7cm × t 2.5cm × d 4.7cm
# 1             Richard Tepe                        h 165mm × w 223mm
#
#      copyright_holder             more_title acquisition_method  \
# 0             missing  The Avenue of Birches           purchase
# 1  erven Richard Tepe        Struik in bloei           purchase
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1808-01-01T00:00:00                     NaN            1660 - 1685
# 1  2000-01-01T00:00:00                     NaN      c. 1900 - c. 1930
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1660.0             17             1660.0            1685.0
# 1               1900.0             19             1900.0            1930.0
#
#    likes
# 0     48
# 1      2

# %%
test.head(2)
# Out:
#               object_id art_series_id  \
# 0  000405d9a5e3f49fc49d         other
# 1  001020bd00b149970f78         other
#
#                                                title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#                                          description  \
# 0                                                NaN
# 1  Portret van Philip Ernst (1585-1629), graaf va...
#
#                                           long_title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#               principal_maker    principal_or_first_maker  \
# 0          Bernardus Bruining          Bernardus Bruining
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn
#
#              sub_title copyright_holder  \
# 0    h 167mm × w 108mm          missing
# 1  h 29.7cm × w 24.1cm          missing
#
#                                           more_title    acquisition_method  \
# 0  Twee personen voor de Duizendjarige den te Wol...              transfer
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...  nationalization 1795
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1994-01-01T00:00:00                     NaN            1850 - 1900
# 1  1798-09-01T00:00:00                     NaN      c. 1609 - c. 1633
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1850.0             19             1850.0            1900.0
# 1               1609.0             17             1609.0            1633.0
#
#    likes
# 0    NaN
# 1    NaN

# %% [markdown]
# # Merge Data

# %%
group = train.groupby('principal_maker')

agg_df = pd.concat([
    group.size().rename('size'), # 著者が何回出てくるか. (value_counts と同じです)
    group['sub_title'].nunique().rename('sub_title_num'), # 著者ごとに何種類の sub_title を持っているか
    group['dating_sorting_date'].agg(['min', 'max', 'mean']), # 著者ごとに描いた年度の最小・最大・平均 (agg に配列を渡すと同時に複数やってくれます)
], axis=1)

agg_df.head()
# Out:
#                  size  sub_title_num     min     max    mean
# principal_maker
# A. Böeseken         5              5  1858.0  1873.0  1865.8
# A. Lutz             1              1  1825.0  1825.0  1825.0
# A. Mansuy           2              2  1860.0  1860.0  1860.0
# A. Nissen           3              1  1860.0  1860.0  1860.0
# A. Roussel          1              1  1905.0  1905.0  1905.0

# %%
train = pd.merge(train, 
         agg_df,
         on='principal_maker', 
         how='left')

test = pd.merge(test, 
         agg_df,
         on='principal_maker', 
         how='left')

# %%
train.columns
# Out:
# Index(['object_id', 'art_series_id', 'title', 'description', 'long_title',
#        'principal_maker', 'principal_or_first_maker', 'sub_title',
#        'copyright_holder', 'more_title', 'acquisition_method',
#        'acquisition_date', 'acquisition_credit_line', 'dating_presenting_date',
#        'dating_sorting_date', 'dating_period', 'dating_year_early',
#        'dating_year_late', 'likes', 'size', 'sub_title_num', 'min', 'max',
#        'mean'],
#       dtype='object')

# %% [markdown]
# # Feature Enginnering

# %%
def create_object_feature(input_df):        
    return input_df['likes'].copy()

create_object_feature(test).head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: likes, dtype: float64

# %%
def create_numeric_feature(input_df):
    use_columns = [
        'dating_period',
        'dating_year_early',
        'dating_year_late'
    ]

    return input_df[use_columns].copy()

create_numeric_feature(train).head(2)
# Out:
#    dating_period  dating_year_early  dating_year_late
# 0             17             1660.0            1685.0
# 1             19             1900.0            1930.0

# %%
def create_categorical_feature(input_df):
    use_columns = [
    'art_series_id',
    'principal_maker',
    'principal_or_first_maker',
    'copyright_holder',
    'acquisition_method',
    ]

    return input_df[use_columns].copy()

create_categorical_feature(train).head(2)
# Out:
#   art_series_id principal_maker principal_or_first_maker    copyright_holder  \
# 0         other    Jan Hackaert             Jan Hackaert             missing
# 1         other    Richard Tepe             Richard Tepe  erven Richard Tepe
#
#   acquisition_method
# 0           purchase
# 1           purchase

# %%
import datetime

def create_acquisition_feature(input_df):
    out_df = pd.DataFrame()
    
    use_columns = [
        'acquisition_date'
    ]
    
    out_df['year'] = pd.to_datetime(input_df['acquisition_date']).dt.year
    out_df['month'] = pd.to_datetime(input_df['acquisition_date']).dt.month
    out_df['dayofweek'] = pd.to_datetime(input_df['acquisition_date']).dt.dayofweek
    out_df['sum_time'] =  10**10 - pd.to_datetime(input_df['acquisition_date']).view('int') // 10**9
    
    return out_df.add_prefix('AcquisitionDate_')

create_acquisition_feature(train).head(2)
# Out:
#    AcquisitionDate_year  AcquisitionDate_month  AcquisitionDate_dayofweek  \
# 0                1808.0                    1.0                        4.0
# 1                2000.0                    1.0                        5.0
#
#    AcquisitionDate_sum_time
# 0               15112288000
# 1                9053315200

# %%
# from util import inf2nan

# def create_principal_maker_info_feature(input_df):
#     '''作者の情報を追加'''
#     out_df = pd.DataFrame()

#     input_df_object_id = input_df['object_id']
    
#     # 作成期間の平均の年を作成
#     train['dating_year_mean'] = (train['dating_year_early'] + train['dating_year_late']) / 2
#     test['dating_year_mean'] = (test['dating_year_early'] + test['dating_year_late']) / 2

#     merge_df = pd.concat([train, test],axis=0).reset_index(drop=True)

#     # 作成期間の平均までに稼いだ良いねの総数、作者の人気度指数
#     out_df['object_id'] = merge_df['object_id']
#     out_df['principal_maker'] = merge_df['principal_maker']
#     out_df['dating_year_mean'] = merge_df['dating_year_mean']
#     out_df['cumsum'] = merge_df.sort_values('dating_year_mean').groupby('principal_maker')['likes'].cumsum()
#     out_df['cumsum_fillnan'] = out_df.sort_values('dating_year_mean').groupby('principal_maker')['cumsum'].ffill()

#     # 作成期間の平均までに出した作品の数
#     tmp_df = pd.DataFrame()
#     tmp_df['object_id'] = train['object_id']
#     tmp_df['cumcount'] = train.sort_values('dating_year_mean').groupby('principal_maker').cumcount()
#     out_df = pd.merge(out_df, tmp_df, on='object_id', how='left')
#     out_df['cumcount_fillnan'] = out_df.sort_values('dating_year_mean').groupby('principal_maker')['cumcount'].ffill()

#     # 作成期間の平均における良いねの作品平均、作者の人気度指数
#     out_df['cumsum_per_cumcount'] = out_df['cumsum_fillnan'] / out_df['cumcount_fillnan']
#     out_df['cumsum_per_cumcount'] = inf2nan(out_df['cumsum_per_cumcount'])
    
#     # anonymousはnanにする
#     anonymous_idx = out_df[out_df['principal_maker'] == 'anonymous'].index
#     out_df.loc[anonymous_idx,['cumsum_fillnan','cumcount_fillnan','cumsum_per_cumcount']] = np.nan
    
#     # filter by id
#     out_df = out_df[out_df['object_id'].isin(input_df_object_id)].reset_index(drop=True)

#     return out_df[['cumsum_fillnan','cumcount_fillnan','cumsum_per_cumcount']].add_prefix('PrincipalMakerInfo_')

# create_principal_maker_info_feature(train).head(2)

# %%
def create_string_length_feature(input_df):
    out_df = pd.DataFrame()

    str_columns = [
        'title', 
        'long_title',
        'sub_title',
        'more_title'
        # and more
    ]

    for c in str_columns:
        out_df[c] = input_df[c].str.len()

    return out_df.add_prefix('StringLength__')

create_string_length_feature(train).head(2)
# Out:
#    StringLength__title  StringLength__long_title  StringLength__sub_title  \
# 0                   21                        48                     39.0
# 1                   15                        64                     17.0
#
#    StringLength__more_title
# 0                      21.0
# 1                      15.0

# %%
def create_count_encoding_feature(input_df):
    use_columns = [
        'acquisition_method',
        'title',
        'principal_maker',
        # and more
    ]

    out_df = pd.DataFrame()
    for column in use_columns:
        vc = train[column].value_counts()
        out_df[column] = input_df[column].map(vc)

    return out_df.add_prefix('CE_')

create_count_encoding_feature(train).head(2)
# Out:
#    CE_acquisition_method  CE_title  CE_principal_maker
# 0                   4253         1                   3
# 1                   4253         1                 180

# %%
def create_one_hot_encoding(input_df):
    use_columns = [
        'acquisition_method',
        'principal_maker'
    ]
    out_df = pd.DataFrame()
    for column in use_columns:

        # あまり巨大な行列にならないよう, 出現回数が 20 回を下回るカテゴリは考慮しない
        vc = train[column].value_counts()
        vc = vc[vc > 20]

        # 明示的に catgories を指定して, input_df によらず列の大きさが等しくなるようにする
        cat = pd.Categorical(input_df[column], categories=vc.index)

        # このタイミングで one-hot 化
        out_i = pd.get_dummies(cat)
        # column が Catgory 型として認識されているので list にして解除する (こうしないと concat でエラーになる)
        out_i.columns = out_i.columns.tolist()
        out_i = out_i.add_prefix(f'{column}=')
        out_df = pd.concat([out_df, out_i], axis=1)
    return out_df

create_one_hot_encoding(train).head(2)
# Out:
#    acquisition_method=purchase  acquisition_method=transfer  \
# 0                            1                            0
# 1                            1                            0
#
#    acquisition_method=gift  acquisition_method=unknown  \
# 0                        0                           0
# 1                        0                           0
#
#    acquisition_method=bequest  acquisition_method=loan  \
# 0                           0                        0
# 1                           0                        0
#
#    acquisition_method=missing  acquisition_method=nationalization 1795  \
# 0                           0                                        0
# 1                           0                                        0
#
#    principal_maker=anonymous  principal_maker=other  ...  \
# 0                          0                      0  ...
# 1                          0                      0  ...
#
#    principal_maker=Rembrandt van Rijn  \
# 0                                   0
# 1                                   0
#
#    principal_maker=C.M. Ferrier & F. von Martens  \
# 0                                              0
# 1                                              0
#
#    principal_maker=Jan Maurits Quinkhard  principal_maker=Adolphe Zimmermans  \
# 0                                      0                                   0
# 1                                      0                                   0
#
#    principal_maker=Cor Jaring  principal_maker=Wouter Johannes van Troostwijk  \
# 0                           0                                               0
# 1                           0                                               0
#
#    principal_maker=Jan Banning  principal_maker=Jean Baptiste August Kessler  \
# 0                            0                                             0
# 1                            0                                             0
#
#    principal_maker=Gerard Edelinck  principal_maker=Augusta Curiel
# 0                                0                               0
# 1                                0                               0
#
# [2 rows x 98 columns]

# %%
import re

#  h 166mm × w 78/54mm

def get_h_from_subtitle(text:str):
    match_cm = re.search(r'h \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'h \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100

def get_w_from_subtitle(text:str):
    match_cm = re.search(r'w \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'w \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        elif match_mm.group()[2:-2] == '78/54':
            return float(78)
        else:
            return float(match_mm.group()[2:-2])/100    

def get_t_from_subtitle(text:str):
    match_cm = re.search(r't \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r't \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100   

def get_d_from_subtitle(text:str):
    match_cm = re.search(r'd \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'd \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100   
        
def create_subtitle_info(input_df):
    out_df = pd.DataFrame()
     
    out_df['subtitle_h'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_h_from_subtitle(x))
    out_df['subtitle_w'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_w_from_subtitle(x))
    out_df['subtitle_t'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_t_from_subtitle(x))
    out_df['subtitle_d'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_d_from_subtitle(x))
    
    out_df['area'] = out_df['subtitle_h'] * out_df['subtitle_w']
    out_df['volume'] = out_df['subtitle_h'] * out_df['subtitle_w'] * out_df['subtitle_t']

    return out_df

create_subtitle_info(test).head(2)
# Out:
#    subtitle_h  subtitle_w  subtitle_t  subtitle_d      area  volume
# 0        1.67        1.08         NaN         NaN    1.8036     NaN
# 1       29.70       24.10         NaN         NaN  715.7700     NaN

# %%
# train_emb_npy = np.load('../../extract_data/train_word_emb.npy')
# test_emb_npy = np.load('../../extract_data/test_word_emb.npy')

# train_emb_df = pd.concat([train['object_id'], pd.DataFrame(train_emb_npy)],axis=1)
# test_emb_df = pd.concat([test['object_id'], pd.DataFrame(test_emb_npy)],axis=1)

# all_df = pd.concat([train_emb_df,test_emb_df],axis=0).reset_index(drop=True)

# all_df.to_pickle('../../extract_data/all_word_emb.pkl')

# %%
def create_word_emb(input_df):
    out_df = pd.DataFrame()
    
    all_emb_df = pd.read_pickle('../../extract_data/all_word_emb.pkl')
    
    input_word_emb = pd.merge(input_df['object_id'], all_emb_df, on='object_id', how='left')
    return input_word_emb[[num for num in range(768)]].add_prefix('WordEmb_')

create_word_emb(test).tail(2)
# Out:
#        WordEmb_0  WordEmb_1  WordEmb_2  WordEmb_3  WordEmb_4  WordEmb_5  \
# 12006  -0.042501   0.036862   0.039394   0.054783  -0.055620  -0.153119
# 12007  -0.777498   0.078685   0.274414  -0.431127   0.061029   0.039257
#
#        WordEmb_6  WordEmb_7  WordEmb_8  WordEmb_9  ...  WordEmb_758  \
# 12006   0.010021   0.173585  -0.000779  -0.121945  ...     0.268849
# 12007  -0.164986   0.329231  -0.602135  -0.045388  ...     0.381525
#
#        WordEmb_759  WordEmb_760  WordEmb_761  WordEmb_762  WordEmb_763  \
# 12006    -0.129603     0.062888     0.120756    -0.125021    -0.322611
# 12007     0.003804     0.270549    -0.396379    -0.319427    -0.290191
#
#        WordEmb_764  WordEmb_765  WordEmb_766  WordEmb_767
# 12006     0.103876    -0.116404     0.032504    -0.025650
# 12007    -0.506566    -0.083110     0.381868     0.443822
#
# [2 rows x 768 columns]

# %%
# https://github.com/nyk510/vivid/blob/master/vivid/utils.py
from contextlib import contextmanager
from time import time

class Timer:
    def __init__(self, logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None, sep=' '):

        if prefix: format_str = str(prefix) + sep + format_str
        if suffix: format_str = format_str + sep + str(suffix)
        self.format_str = format_str
        self.logger = logger
        self.start = None
        self.end = None

    @property
    def duration(self):
        if self.end is None:
            return 0
        return self.end - self.start

    def __enter__(self):
        self.start = time()

    def __exit__(self, exc_type, exc_val, exc_tb):
        self.end = time()
        out_str = self.format_str.format(self.duration)
        if self.logger:
            self.logger.info(out_str)
        else:
            print(out_str)

# %%
from tqdm import tqdm

def to_feature(input_df):
    """input_df を特徴量行列に変換した新しいデータフレームを返す.
    """

    processors = [
        create_object_feature,
        create_numeric_feature,
        create_categorical_feature,
        create_acquisition_feature,
        # create_principal_maker_info_feature,
        create_string_length_feature,
        create_count_encoding_feature,
        create_one_hot_encoding,
        create_subtitle_info,
        create_word_emb
    ]

    out_df = pd.DataFrame()

    for func in tqdm(processors, total=len(processors)):
        with Timer(prefix='create' + func.__name__ + ' '):
            _df = func(input_df)
        # 長さが等しいことをチェック (ずれている場合, func の実装がおかしい)
        assert len(_df) == len(input_df), func.__name__
        out_df = pd.concat([out_df, _df], axis=1)

    return out_df

train_feat= to_feature(train)
test_feat = to_feature(test)

train = train_feat.copy()
test = test_feat.copy()
# Out:
#  89%|████████▉ | 8/9 [00:00<00:00, 46.91it/s]
# createcreate_object_feature  0.001[s]
# createcreate_numeric_feature  0.001[s]
# createcreate_categorical_feature  0.001[s]
# createcreate_acquisition_feature  0.022[s]
# createcreate_string_length_feature  0.015[s]
# createcreate_count_encoding_feature  0.011[s]
# createcreate_one_hot_encoding  0.009[s]
# createcreate_subtitle_info  0.083[s]
# 100%|██████████| 9/9 [00:00<00:00, 24.88it/s]
#  89%|████████▉ | 8/9 [00:00<00:00, 48.11it/s]
# createcreate_word_emb  0.167[s]
# createcreate_object_feature  0.000[s]
# createcreate_numeric_feature  0.002[s]
# createcreate_categorical_feature  0.001[s]
# createcreate_acquisition_feature  0.014[s]
# createcreate_string_length_feature  0.018[s]
# createcreate_count_encoding_feature  0.013[s]
# createcreate_one_hot_encoding  0.009[s]
# createcreate_subtitle_info  0.080[s]
# 100%|██████████| 9/9 [00:00<00:00, 23.83it/s]
# createcreate_word_emb  0.191[s]

# %%
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %% [markdown]
# # train

# %%
train.isnull().sum()
# Out:
# likes                 0
# dating_period         0
# dating_year_early    10
# dating_year_late     38
# art_series_id         0
#                      ..
# WordEmb_763           0
# WordEmb_764           0
# WordEmb_765           0
# WordEmb_766           0
# WordEmb_767           0
# Length: 892, dtype: int64

# %%
test.head(2)
# Out:
#    likes  dating_period  dating_year_early  dating_year_late art_series_id  \
# 0    NaN             19             1850.0            1900.0         other
# 1    NaN             17             1609.0            1633.0         other
#
#               principal_maker    principal_or_first_maker copyright_holder  \
# 0          Bernardus Bruining          Bernardus Bruining          missing
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn          missing
#
#      acquisition_method  AcquisitionDate_year  ...  WordEmb_758  WordEmb_759  \
# 0              transfer                1994.0  ...     0.268849    -0.129603
# 1  nationalization 1795                1798.0  ...     0.394220    -0.281017
#
#    WordEmb_760  WordEmb_761  WordEmb_762  WordEmb_763  WordEmb_764  \
# 0     0.062888     0.120756    -0.125021    -0.322611     0.103876
# 1     0.191040    -0.510283    -0.056549    -0.350427    -0.791569
#
#    WordEmb_765  WordEmb_766  WordEmb_767
# 0    -0.116404     0.032504    -0.025650
# 1    -0.017803     0.362915     0.348247
#
# [2 rows x 892 columns]

# %% [markdown]
# # reduce mem usage

# %%
# from util import reduce_mem_usage
# train_feat_df = reduce_mem_usage(train_feat_df)
# test_feat_df = reduce_mem_usage(test_feat_df)

# %% [markdown]
# # Lable Encoding

# %%
cat_col = train.select_dtypes('O').columns.tolist()

# %%
from fe import label_encode
train, test = label_encode(train, test, cat_col)

# %%
train.dtypes
# Out:
# likes                  int64
# dating_period          int64
# dating_year_early    float64
# dating_year_late     float64
# art_series_id          int64
#                       ...
# WordEmb_763          float32
# WordEmb_764          float32
# WordEmb_765          float32
# WordEmb_766          float32
# WordEmb_767          float32
# Length: 892, dtype: object

# %% [markdown]
# # add fold

# %%
from fold import add_fold_bin_skf
train = add_fold_bin_skf(train, train[cfg['target']], fold_num=5, bins=[0,1,10,100,1000, 27392])

# %% [markdown]
# # Target Encoding

# %%
train['dating_period']
# Out:
# 0        17
# 1        19
# 2        19
# 3        19
# 4        19
#          ..
# 12021    19
# 12022    18
# 12023    18
# 12024    17
# 12025    15
# Name: dating_period, Length: 12026, dtype: int64

# %%
# target_enc_list = [
#     # 'art_series_id',
#     'principal_maker',
#     'principal_or_first_maker',
#     'copyright_holder',
#     'acquisition_method',
#     'dating_period'
# ]

# from fe import target_encoding
# train, test = target_encoding(train, 
#                               test, 
#                               target = cfg['target'], 
#                               target_enc_list = target_enc_list, 
#                               fold_num = cfg['fold_num']
#                              )

# %% [markdown]
# # Make Model

# %%
use_col = train.columns.tolist()
use_col.remove('fold')
use_col.remove(cfg['target'])

# %%
use_col
# Out:
# ['dating_period',
#  'dating_year_early',
#  'dating_year_late',
#  'art_series_id',
#  'principal_maker',
#  'principal_or_first_maker',
#  'copyright_holder',
#  'acquisition_method',
#  'AcquisitionDate_year',
#  'AcquisitionDate_month',
#  'AcquisitionDate_dayofweek',
#  'AcquisitionDate_sum_time',
#  'StringLength__title',
#  'StringLength__long_title',
#  'StringLength__sub_title',
#  'StringLength__more_title',
#  'CE_acquisition_method',
#  'CE_title',
#  'CE_principal_maker',
#  'acquisition_method=purchase',
#  'acquisition_method=transfer',
#  'acquisition_method=gift',
#  'acquisition_method=unknown',
#  'acquisition_method=bequest',
#  'acquisition_method=loan',
#  'acquisition_method=missing',
#  'acquisition_method=nationalization 1795',
#  'principal_maker=anonymous',
#  'principal_maker=other',
#  'principal_maker=Johann Sadeler (I)',
#  'principal_maker=Bernard Picart',
#  'principal_maker=Richard Tepe',
#  'principal_maker=anoniem (Monumentenzorg)',
#  'principal_maker=Jan Luyken',
#  'principal_maker=Raphaël Sadeler (I)',
#  'principal_maker=Woodbury & Page',
#  'principal_maker=Romeyn de Hooghe',
#  'principal_maker=Aegidius Sadeler',
#  'principal_maker=Giorgio Sommer',
#  'principal_maker=Willem Diepraam',
#  'principal_maker=Jacob Olie jr.',
#  'principal_maker=Geldolph Adriaan Kessler',
#  'principal_maker=L. Heldring',
#  'principal_maker=Abraham Rademaker',
#  'principal_maker=Hermanus Jan Hendrik van Rijkelijkhuysen',
#  'principal_maker=Crispijn van de Passe (I)',
#  'principal_maker=Jan Harmensz. Muller',
#  'principal_maker=Johanna Margaretha Piek',
#  'principal_maker=Cornelis Galle (I)',
#  'principal_maker=Jacob de Gheyn (II)',
#  'principal_maker=Cornelis Ploos van Amstel',
#  'principal_maker=Théodore van Lelyveld',
#  'principal_maker=Jacob van der Schley',
#  'principal_maker=Daniël Veelwaard (I)',
#  'principal_maker=Jan Frederik Christiaan Reckleben',
#  'principal_maker=Paulus Pontius',
#  'principal_maker=Albert Greiner',
#  'principal_maker=Hendrick Goltzius',
#  'principal_maker=Henry Pauw van Wieldrecht',
#  'principal_maker=Francis Frith',
#  'principal_maker=Heinrich Aldegrever',
#  'principal_maker=Roelant Roghman',
#  'principal_maker=Theodoor Koning',
#  'principal_maker=Adolphe Burdet',
#  'principal_maker=Jacques Lalaing',
#  'principal_maker=G. Dangereux',
#  'principal_maker=Bonfils',
#  'principal_maker=Juan Laurent',
#  'principal_maker=Philip Henry Delamotte',
#  'principal_maker=Fratelli Alinari',
#  'principal_maker=Henry W. Taunt',
#  'principal_maker=Isidore Kinsbergen',
#  'principal_maker=Atelier Kurkdjian',
#  'principal_maker=Charles Rochussen',
#  'principal_maker=Johann Heinrich Maria Hubert Rennefeld',
#  'principal_maker=Paul Güssfeldt',
#  'principal_maker=Carl Cristiaan Fuchs',
#  'principal_maker=Jan van de Velde (II)',
#  'principal_maker=Caspar Luyken',
#  'principal_maker=Eberhard Cornelis Rahms',
#  'principal_maker=Samuel Bourne',
#  'principal_maker=Jozef Van Ruyssevelt',
#  'principal_maker=Waldemar Titzenthaler',
#  'principal_maker=Gabriel Huquier',
#  'principal_maker=George Hendrik Breitner',
#  'principal_maker=Theodoor van Thulden',
#  'principal_maker=Jean Baptiste Vanmour',
#  'principal_maker=Joost van Geel',
#  'principal_maker=Giacomo Brogi',
#  'principal_maker=James Higson',
#  'principal_maker=Hendrik Roosing',
#  'principal_maker=Dirck Volckertsz. Coornhert',
#  'principal_maker=Schelte Adamsz. Bolswert',
#  'principal_maker=Herman Salzwedel',
#  'principal_maker=Christiaan Benjamin Nieuwenhuis',
#  'principal_maker=Gustave Eugène Chauffourier',
#  'principal_maker=O. Hisgen & Co.',
#  'principal_maker=Charles Thurston Thompson',
#  'principal_maker=Boëtius Adamsz. Bolswert',
#  'principal_maker=Maurits Verveer',
#  'principal_maker=Heinrich Ernst & Co',
#  'principal_maker=Jan Goedeljee',
#  'principal_maker=Arnoud van Halen',
#  'principal_maker=Kornelis Willem Schorteldoek',
#  'principal_maker=Simon Fokke',
#  'principal_maker=Ohannes Kurkdjian',
#  'principal_maker=James Valentine',
#  'principal_maker=Rembrandt van Rijn',
#  'principal_maker=C.M. Ferrier & F. von Martens',
#  'principal_maker=Jan Maurits Quinkhard',
#  'principal_maker=Adolphe Zimmermans',
#  'principal_maker=Cor Jaring',
#  'principal_maker=Wouter Johannes van Troostwijk',
#  'principal_maker=Jan Banning',
#  'principal_maker=Jean Baptiste August Kessler',
#  'principal_maker=Gerard Edelinck',
#  'principal_maker=Augusta Curiel',
#  'subtitle_h',
#  'subtitle_w',
#  'subtitle_t',
#  'subtitle_d',
#  'area',
#  'volume',
#  'WordEmb_0',
#  'WordEmb_1',
#  'WordEmb_2',
#  'WordEmb_3',
#  'WordEmb_4',
#  'WordEmb_5',
#  'WordEmb_6',
#  'WordEmb_7',
#  'WordEmb_8',
#  'WordEmb_9',
#  'WordEmb_10',
#  'WordEmb_11',
#  'WordEmb_12',
#  'WordEmb_13',
#  'WordEmb_14',
#  'WordEmb_15',
#  'WordEmb_16',
#  'WordEmb_17',
#  'WordEmb_18',
#  'WordEmb_19',
#  'WordEmb_20',
#  'WordEmb_21',
#  'WordEmb_22',
#  'WordEmb_23',
#  'WordEmb_24',
#  'WordEmb_25',
#  'WordEmb_26',
#  'WordEmb_27',
#  'WordEmb_28',
#  'WordEmb_29',
#  'WordEmb_30',
#  'WordEmb_31',
#  'WordEmb_32',
#  'WordEmb_33',
#  'WordEmb_34',
#  'WordEmb_35',
#  'WordEmb_36',
#  'WordEmb_37',
#  'WordEmb_38',
#  'WordEmb_39',
#  'WordEmb_40',
#  'WordEmb_41',
#  'WordEmb_42',
#  'WordEmb_43',
#  'WordEmb_44',
#  'WordEmb_45',
#  'WordEmb_46',
#  'WordEmb_47',
#  'WordEmb_48',
#  'WordEmb_49',
#  'WordEmb_50',
#  'WordEmb_51',
#  'WordEmb_52',
#  'WordEmb_53',
#  'WordEmb_54',
#  'WordEmb_55',
#  'WordEmb_56',
#  'WordEmb_57',
#  'WordEmb_58',
#  'WordEmb_59',
#  'WordEmb_60',
#  'WordEmb_61',
#  'WordEmb_62',
#  'WordEmb_63',
#  'WordEmb_64',
#  'WordEmb_65',
#  'WordEmb_66',
#  'WordEmb_67',
#  'WordEmb_68',
#  'WordEmb_69',
#  'WordEmb_70',
#  'WordEmb_71',
#  'WordEmb_72',
#  'WordEmb_73',
#  'WordEmb_74',
#  'WordEmb_75',
#  'WordEmb_76',
#  'WordEmb_77',
#  'WordEmb_78',
#  'WordEmb_79',
#  'WordEmb_80',
#  'WordEmb_81',
#  'WordEmb_82',
#  'WordEmb_83',
#  'WordEmb_84',
#  'WordEmb_85',
#  'WordEmb_86',
#  'WordEmb_87',
#  'WordEmb_88',
#  'WordEmb_89',
#  'WordEmb_90',
#  'WordEmb_91',
#  'WordEmb_92',
#  'WordEmb_93',
#  'WordEmb_94',
#  'WordEmb_95',
#  'WordEmb_96',
#  'WordEmb_97',
#  'WordEmb_98',
#  'WordEmb_99',
#  'WordEmb_100',
#  'WordEmb_101',
#  'WordEmb_102',
#  'WordEmb_103',
#  'WordEmb_104',
#  'WordEmb_105',
#  'WordEmb_106',
#  'WordEmb_107',
#  'WordEmb_108',
#  'WordEmb_109',
#  'WordEmb_110',
#  'WordEmb_111',
#  'WordEmb_112',
#  'WordEmb_113',
#  'WordEmb_114',
#  'WordEmb_115',
#  'WordEmb_116',
#  'WordEmb_117',
#  'WordEmb_118',
#  'WordEmb_119',
#  'WordEmb_120',
#  'WordEmb_121',
#  'WordEmb_122',
#  'WordEmb_123',
#  'WordEmb_124',
#  'WordEmb_125',
#  'WordEmb_126',
#  'WordEmb_127',
#  'WordEmb_128',
#  'WordEmb_129',
#  'WordEmb_130',
#  'WordEmb_131',
#  'WordEmb_132',
#  'WordEmb_133',
#  'WordEmb_134',
#  'WordEmb_135',
#  'WordEmb_136',
#  'WordEmb_137',
#  'WordEmb_138',
#  'WordEmb_139',
#  'WordEmb_140',
#  'WordEmb_141',
#  'WordEmb_142',
#  'WordEmb_143',
#  'WordEmb_144',
#  'WordEmb_145',
#  'WordEmb_146',
#  'WordEmb_147',
#  'WordEmb_148',
#  'WordEmb_149',
#  'WordEmb_150',
#  'WordEmb_151',
#  'WordEmb_152',
#  'WordEmb_153',
#  'WordEmb_154',
#  'WordEmb_155',
#  'WordEmb_156',
#  'WordEmb_157',
#  'WordEmb_158',
#  'WordEmb_159',
#  'WordEmb_160',
#  'WordEmb_161',
#  'WordEmb_162',
#  'WordEmb_163',
#  'WordEmb_164',
#  'WordEmb_165',
#  'WordEmb_166',
#  'WordEmb_167',
#  'WordEmb_168',
#  'WordEmb_169',
#  'WordEmb_170',
#  'WordEmb_171',
#  'WordEmb_172',
#  'WordEmb_173',
#  'WordEmb_174',
#  'WordEmb_175',
#  'WordEmb_176',
#  'WordEmb_177',
#  'WordEmb_178',
#  'WordEmb_179',
#  'WordEmb_180',
#  'WordEmb_181',
#  'WordEmb_182',
#  'WordEmb_183',
#  'WordEmb_184',
#  'WordEmb_185',
#  'WordEmb_186',
#  'WordEmb_187',
#  'WordEmb_188',
#  'WordEmb_189',
#  'WordEmb_190',
#  'WordEmb_191',
#  'WordEmb_192',
#  'WordEmb_193',
#  'WordEmb_194',
#  'WordEmb_195',
#  'WordEmb_196',
#  'WordEmb_197',
#  'WordEmb_198',
#  'WordEmb_199',
#  'WordEmb_200',
#  'WordEmb_201',
#  'WordEmb_202',
#  'WordEmb_203',
#  'WordEmb_204',
#  'WordEmb_205',
#  'WordEmb_206',
#  'WordEmb_207',
#  'WordEmb_208',
#  'WordEmb_209',
#  'WordEmb_210',
#  'WordEmb_211',
#  'WordEmb_212',
#  'WordEmb_213',
#  'WordEmb_214',
#  'WordEmb_215',
#  'WordEmb_216',
#  'WordEmb_217',
#  'WordEmb_218',
#  'WordEmb_219',
#  'WordEmb_220',
#  'WordEmb_221',
#  'WordEmb_222',
#  'WordEmb_223',
#  'WordEmb_224',
#  'WordEmb_225',
#  'WordEmb_226',
#  'WordEmb_227',
#  'WordEmb_228',
#  'WordEmb_229',
#  'WordEmb_230',
#  'WordEmb_231',
#  'WordEmb_232',
#  'WordEmb_233',
#  'WordEmb_234',
#  'WordEmb_235',
#  'WordEmb_236',
#  'WordEmb_237',
#  'WordEmb_238',
#  'WordEmb_239',
#  'WordEmb_240',
#  'WordEmb_241',
#  'WordEmb_242',
#  'WordEmb_243',
#  'WordEmb_244',
#  'WordEmb_245',
#  'WordEmb_246',
#  'WordEmb_247',
#  'WordEmb_248',
#  'WordEmb_249',
#  'WordEmb_250',
#  'WordEmb_251',
#  'WordEmb_252',
#  'WordEmb_253',
#  'WordEmb_254',
#  'WordEmb_255',
#  'WordEmb_256',
#  'WordEmb_257',
#  'WordEmb_258',
#  'WordEmb_259',
#  'WordEmb_260',
#  'WordEmb_261',
#  'WordEmb_262',
#  'WordEmb_263',
#  'WordEmb_264',
#  'WordEmb_265',
#  'WordEmb_266',
#  'WordEmb_267',
#  'WordEmb_268',
#  'WordEmb_269',
#  'WordEmb_270',
#  'WordEmb_271',
#  'WordEmb_272',
#  'WordEmb_273',
#  'WordEmb_274',
#  'WordEmb_275',
#  'WordEmb_276',
#  'WordEmb_277',
#  'WordEmb_278',
#  'WordEmb_279',
#  'WordEmb_280',
#  'WordEmb_281',
#  'WordEmb_282',
#  'WordEmb_283',
#  'WordEmb_284',
#  'WordEmb_285',
#  'WordEmb_286',
#  'WordEmb_287',
#  'WordEmb_288',
#  'WordEmb_289',
#  'WordEmb_290',
#  'WordEmb_291',
#  'WordEmb_292',
#  'WordEmb_293',
#  'WordEmb_294',
#  'WordEmb_295',
#  'WordEmb_296',
#  'WordEmb_297',
#  'WordEmb_298',
#  'WordEmb_299',
#  'WordEmb_300',
#  'WordEmb_301',
#  'WordEmb_302',
#  'WordEmb_303',
#  'WordEmb_304',
#  'WordEmb_305',
#  'WordEmb_306',
#  'WordEmb_307',
#  'WordEmb_308',
#  'WordEmb_309',
#  'WordEmb_310',
#  'WordEmb_311',
#  'WordEmb_312',
#  'WordEmb_313',
#  'WordEmb_314',
#  'WordEmb_315',
#  'WordEmb_316',
#  'WordEmb_317',
#  'WordEmb_318',
#  'WordEmb_319',
#  'WordEmb_320',
#  'WordEmb_321',
#  'WordEmb_322',
#  'WordEmb_323',
#  'WordEmb_324',
#  'WordEmb_325',
#  'WordEmb_326',
#  'WordEmb_327',
#  'WordEmb_328',
#  'WordEmb_329',
#  'WordEmb_330',
#  'WordEmb_331',
#  'WordEmb_332',
#  'WordEmb_333',
#  'WordEmb_334',
#  'WordEmb_335',
#  'WordEmb_336',
#  'WordEmb_337',
#  'WordEmb_338',
#  'WordEmb_339',
#  'WordEmb_340',
#  'WordEmb_341',
#  'WordEmb_342',
#  'WordEmb_343',
#  'WordEmb_344',
#  'WordEmb_345',
#  'WordEmb_346',
#  'WordEmb_347',
#  'WordEmb_348',
#  'WordEmb_349',
#  'WordEmb_350',
#  'WordEmb_351',
#  'WordEmb_352',
#  'WordEmb_353',
#  'WordEmb_354',
#  'WordEmb_355',
#  'WordEmb_356',
#  'WordEmb_357',
#  'WordEmb_358',
#  'WordEmb_359',
#  'WordEmb_360',
#  'WordEmb_361',
#  'WordEmb_362',
#  'WordEmb_363',
#  'WordEmb_364',
#  'WordEmb_365',
#  'WordEmb_366',
#  'WordEmb_367',
#  'WordEmb_368',
#  'WordEmb_369',
#  'WordEmb_370',
#  'WordEmb_371',
#  'WordEmb_372',
#  'WordEmb_373',
#  'WordEmb_374',
#  'WordEmb_375',
#  'WordEmb_376',
#  'WordEmb_377',
#  'WordEmb_378',
#  'WordEmb_379',
#  'WordEmb_380',
#  'WordEmb_381',
#  'WordEmb_382',
#  'WordEmb_383',
#  'WordEmb_384',
#  'WordEmb_385',
#  'WordEmb_386',
#  'WordEmb_387',
#  'WordEmb_388',
#  'WordEmb_389',
#  'WordEmb_390',
#  'WordEmb_391',
#  'WordEmb_392',
#  'WordEmb_393',
#  'WordEmb_394',
#  'WordEmb_395',
#  'WordEmb_396',
#  'WordEmb_397',
#  'WordEmb_398',
#  'WordEmb_399',
#  'WordEmb_400',
#  'WordEmb_401',
#  'WordEmb_402',
#  'WordEmb_403',
#  'WordEmb_404',
#  'WordEmb_405',
#  'WordEmb_406',
#  'WordEmb_407',
#  'WordEmb_408',
#  'WordEmb_409',
#  'WordEmb_410',
#  'WordEmb_411',
#  'WordEmb_412',
#  'WordEmb_413',
#  'WordEmb_414',
#  'WordEmb_415',
#  'WordEmb_416',
#  'WordEmb_417',
#  'WordEmb_418',
#  'WordEmb_419',
#  'WordEmb_420',
#  'WordEmb_421',
#  'WordEmb_422',
#  'WordEmb_423',
#  'WordEmb_424',
#  'WordEmb_425',
#  'WordEmb_426',
#  'WordEmb_427',
#  'WordEmb_428',
#  'WordEmb_429',
#  'WordEmb_430',
#  'WordEmb_431',
#  'WordEmb_432',
#  'WordEmb_433',
#  'WordEmb_434',
#  'WordEmb_435',
#  'WordEmb_436',
#  'WordEmb_437',
#  'WordEmb_438',
#  'WordEmb_439',
#  'WordEmb_440',
#  'WordEmb_441',
#  'WordEmb_442',
#  'WordEmb_443',
#  'WordEmb_444',
#  'WordEmb_445',
#  'WordEmb_446',
#  'WordEmb_447',
#  'WordEmb_448',
#  'WordEmb_449',
#  'WordEmb_450',
#  'WordEmb_451',
#  'WordEmb_452',
#  'WordEmb_453',
#  'WordEmb_454',
#  'WordEmb_455',
#  'WordEmb_456',
#  'WordEmb_457',
#  'WordEmb_458',
#  'WordEmb_459',
#  'WordEmb_460',
#  'WordEmb_461',
#  'WordEmb_462',
#  'WordEmb_463',
#  'WordEmb_464',
#  'WordEmb_465',
#  'WordEmb_466',
#  'WordEmb_467',
#  'WordEmb_468',
#  'WordEmb_469',
#  'WordEmb_470',
#  'WordEmb_471',
#  'WordEmb_472',
#  'WordEmb_473',
#  'WordEmb_474',
#  'WordEmb_475',
#  'WordEmb_476',
#  'WordEmb_477',
#  'WordEmb_478',
#  'WordEmb_479',
#  'WordEmb_480',
#  'WordEmb_481',
#  'WordEmb_482',
#  'WordEmb_483',
#  'WordEmb_484',
#  'WordEmb_485',
#  'WordEmb_486',
#  'WordEmb_487',
#  'WordEmb_488',
#  'WordEmb_489',
#  'WordEmb_490',
#  'WordEmb_491',
#  'WordEmb_492',
#  'WordEmb_493',
#  'WordEmb_494',
#  'WordEmb_495',
#  'WordEmb_496',
#  'WordEmb_497',
#  'WordEmb_498',
#  'WordEmb_499',
#  'WordEmb_500',
#  'WordEmb_501',
#  'WordEmb_502',
#  'WordEmb_503',
#  'WordEmb_504',
#  'WordEmb_505',
#  'WordEmb_506',
#  'WordEmb_507',
#  'WordEmb_508',
#  'WordEmb_509',
#  'WordEmb_510',
#  'WordEmb_511',
#  'WordEmb_512',
#  'WordEmb_513',
#  'WordEmb_514',
#  'WordEmb_515',
#  'WordEmb_516',
#  'WordEmb_517',
#  'WordEmb_518',
#  'WordEmb_519',
#  'WordEmb_520',
#  'WordEmb_521',
#  'WordEmb_522',
#  'WordEmb_523',
#  'WordEmb_524',
#  'WordEmb_525',
#  'WordEmb_526',
#  'WordEmb_527',
#  'WordEmb_528',
#  'WordEmb_529',
#  'WordEmb_530',
#  'WordEmb_531',
#  'WordEmb_532',
#  'WordEmb_533',
#  'WordEmb_534',
#  'WordEmb_535',
#  'WordEmb_536',
#  'WordEmb_537',
#  'WordEmb_538',
#  'WordEmb_539',
#  'WordEmb_540',
#  'WordEmb_541',
#  'WordEmb_542',
#  'WordEmb_543',
#  'WordEmb_544',
#  'WordEmb_545',
#  'WordEmb_546',
#  'WordEmb_547',
#  'WordEmb_548',
#  'WordEmb_549',
#  'WordEmb_550',
#  'WordEmb_551',
#  'WordEmb_552',
#  'WordEmb_553',
#  'WordEmb_554',
#  'WordEmb_555',
#  'WordEmb_556',
#  'WordEmb_557',
#  'WordEmb_558',
#  'WordEmb_559',
#  'WordEmb_560',
#  'WordEmb_561',
#  'WordEmb_562',
#  'WordEmb_563',
#  'WordEmb_564',
#  'WordEmb_565',
#  'WordEmb_566',
#  'WordEmb_567',
#  'WordEmb_568',
#  'WordEmb_569',
#  'WordEmb_570',
#  'WordEmb_571',
#  'WordEmb_572',
#  'WordEmb_573',
#  'WordEmb_574',
#  'WordEmb_575',
#  'WordEmb_576',
#  'WordEmb_577',
#  'WordEmb_578',
#  'WordEmb_579',
#  'WordEmb_580',
#  'WordEmb_581',
#  'WordEmb_582',
#  'WordEmb_583',
#  'WordEmb_584',
#  'WordEmb_585',
#  'WordEmb_586',
#  'WordEmb_587',
#  'WordEmb_588',
#  'WordEmb_589',
#  'WordEmb_590',
#  'WordEmb_591',
#  'WordEmb_592',
#  'WordEmb_593',
#  'WordEmb_594',
#  'WordEmb_595',
#  'WordEmb_596',
#  'WordEmb_597',
#  'WordEmb_598',
#  'WordEmb_599',
#  'WordEmb_600',
#  'WordEmb_601',
#  'WordEmb_602',
#  'WordEmb_603',
#  'WordEmb_604',
#  'WordEmb_605',
#  'WordEmb_606',
#  'WordEmb_607',
#  'WordEmb_608',
#  'WordEmb_609',
#  'WordEmb_610',
#  'WordEmb_611',
#  'WordEmb_612',
#  'WordEmb_613',
#  'WordEmb_614',
#  'WordEmb_615',
#  'WordEmb_616',
#  'WordEmb_617',
#  'WordEmb_618',
#  'WordEmb_619',
#  'WordEmb_620',
#  'WordEmb_621',
#  'WordEmb_622',
#  'WordEmb_623',
#  'WordEmb_624',
#  'WordEmb_625',
#  'WordEmb_626',
#  'WordEmb_627',
#  'WordEmb_628',
#  'WordEmb_629',
#  'WordEmb_630',
#  'WordEmb_631',
#  'WordEmb_632',
#  'WordEmb_633',
#  'WordEmb_634',
#  'WordEmb_635',
#  'WordEmb_636',
#  'WordEmb_637',
#  'WordEmb_638',
#  'WordEmb_639',
#  'WordEmb_640',
#  'WordEmb_641',
#  'WordEmb_642',
#  'WordEmb_643',
#  'WordEmb_644',
#  'WordEmb_645',
#  'WordEmb_646',
#  'WordEmb_647',
#  'WordEmb_648',
#  'WordEmb_649',
#  'WordEmb_650',
#  'WordEmb_651',
#  'WordEmb_652',
#  'WordEmb_653',
#  'WordEmb_654',
#  'WordEmb_655',
#  'WordEmb_656',
#  'WordEmb_657',
#  'WordEmb_658',
#  'WordEmb_659',
#  'WordEmb_660',
#  'WordEmb_661',
#  'WordEmb_662',
#  'WordEmb_663',
#  'WordEmb_664',
#  'WordEmb_665',
#  'WordEmb_666',
#  'WordEmb_667',
#  'WordEmb_668',
#  'WordEmb_669',
#  'WordEmb_670',
#  'WordEmb_671',
#  'WordEmb_672',
#  'WordEmb_673',
#  'WordEmb_674',
#  'WordEmb_675',
#  'WordEmb_676',
#  'WordEmb_677',
#  'WordEmb_678',
#  'WordEmb_679',
#  'WordEmb_680',
#  'WordEmb_681',
#  'WordEmb_682',
#  'WordEmb_683',
#  'WordEmb_684',
#  'WordEmb_685',
#  'WordEmb_686',
#  'WordEmb_687',
#  'WordEmb_688',
#  'WordEmb_689',
#  'WordEmb_690',
#  'WordEmb_691',
#  'WordEmb_692',
#  'WordEmb_693',
#  'WordEmb_694',
#  'WordEmb_695',
#  'WordEmb_696',
#  'WordEmb_697',
#  'WordEmb_698',
#  'WordEmb_699',
#  'WordEmb_700',
#  'WordEmb_701',
#  'WordEmb_702',
#  'WordEmb_703',
#  'WordEmb_704',
#  'WordEmb_705',
#  'WordEmb_706',
#  'WordEmb_707',
#  'WordEmb_708',
#  'WordEmb_709',
#  'WordEmb_710',
#  'WordEmb_711',
#  'WordEmb_712',
#  'WordEmb_713',
#  'WordEmb_714',
#  'WordEmb_715',
#  'WordEmb_716',
#  'WordEmb_717',
#  'WordEmb_718',
#  'WordEmb_719',
#  'WordEmb_720',
#  'WordEmb_721',
#  'WordEmb_722',
#  'WordEmb_723',
#  'WordEmb_724',
#  'WordEmb_725',
#  'WordEmb_726',
#  'WordEmb_727',
#  'WordEmb_728',
#  'WordEmb_729',
#  'WordEmb_730',
#  'WordEmb_731',
#  'WordEmb_732',
#  'WordEmb_733',
#  'WordEmb_734',
#  'WordEmb_735',
#  'WordEmb_736',
#  'WordEmb_737',
#  'WordEmb_738',
#  'WordEmb_739',
#  'WordEmb_740',
#  'WordEmb_741',
#  'WordEmb_742',
#  'WordEmb_743',
#  'WordEmb_744',
#  'WordEmb_745',
#  'WordEmb_746',
#  'WordEmb_747',
#  'WordEmb_748',
#  'WordEmb_749',
#  'WordEmb_750',
#  'WordEmb_751',
#  'WordEmb_752',
#  'WordEmb_753',
#  'WordEmb_754',
#  'WordEmb_755',
#  'WordEmb_756',
#  'WordEmb_757',
#  'WordEmb_758',
#  'WordEmb_759',
#  'WordEmb_760',
#  'WordEmb_761',
#  'WordEmb_762',
#  'WordEmb_763',
#  'WordEmb_764',
#  'WordEmb_765',
#  'WordEmb_766',
#  'WordEmb_767']

# %%
# 学習直前でwandbにログイン、こうしないと頻繁にnotebookが落ちる
from use_wandb import use_wandb
use_wandb(params=cfg['params'], PROJECT_NAME=cfg['competition_name'], TRIAL_NAME=TRIAL_NAME)
# e99ecbcc2d9a775a09280213a06af1cf174d0fe0
# Out:
# wandb: Currently logged in as: sinchir0 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">13_remove_tarenc</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sinchir0/atmacup10" target="_blank">https://wandb.ai/sinchir0/atmacup10</a><br/>
#                 Run page: <a href="https://wandb.ai/sinchir0/atmacup10/runs/2ceb6lgb" target="_blank">https://wandb.ai/sinchir0/atmacup10/runs/2ceb6lgb</a><br/>
#                 Run data is saved locally in <code>/Users/shinichiro.saito/atmacup/my_pipeline/experiments/notebook/wandb/run-20210308_001943-2ceb6lgb</code><br/><br/>

# %%
from fe import target_encoding
from lgbm import LGBM

lgbm = LGBM(train=train,
  test=test,
  target='likes',
  use_col=use_col,
  cat_col=cat_col,
  cfg=cfg,
  OUTPUT_DIR=OUTPUT_DIR,
  DO_FIT=True,
  DO_SEED_AVE=False,
  DEBUG=False,
  is_target_log=True)

feature_importance_df, order = lgbm.feature_importance(PLOT=False)
# Out:
# --------------FOLDS : 0 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.20608	valid_1's rmse: 1.23931
# [200]	training's rmse: 1.05261	valid_1's rmse: 1.127
# [300]	training's rmse: 0.988317	valid_1's rmse: 1.09983
# [400]	training's rmse: 0.943111	valid_1's rmse: 1.08833
# [500]	training's rmse: 0.907066	valid_1's rmse: 1.08106
# [600]	training's rmse: 0.877202	valid_1's rmse: 1.07641
# [700]	training's rmse: 0.850498	valid_1's rmse: 1.07271
# [800]	training's rmse: 0.827053	valid_1's rmse: 1.07028
# [900]	training's rmse: 0.806046	valid_1's rmse: 1.0684
# [1000]	training's rmse: 0.786518	valid_1's rmse: 1.06605
# [1100]	training's rmse: 0.768527	valid_1's rmse: 1.06455
# [1200]	training's rmse: 0.751416	valid_1's rmse: 1.06282
# [1300]	training's rmse: 0.735588	valid_1's rmse: 1.06104
# [1400]	training's rmse: 0.720238	valid_1's rmse: 1.05954
# [1500]	training's rmse: 0.706502	valid_1's rmse: 1.05824
# [1600]	training's rmse: 0.693185	valid_1's rmse: 1.05705
# [1700]	training's rmse: 0.680317	valid_1's rmse: 1.05577
# [1800]	training's rmse: 0.668322	valid_1's rmse: 1.05476
# [1900]	training's rmse: 0.65679	valid_1's rmse: 1.05361
# [2000]	training's rmse: 0.645912	valid_1's rmse: 1.05277
# [2100]	training's rmse: 0.635841	valid_1's rmse: 1.05164
# [2200]	training's rmse: 0.625723	valid_1's rmse: 1.05085
# [2300]	training's rmse: 0.615939	valid_1's rmse: 1.05033
# [2400]	training's rmse: 0.607028	valid_1's rmse: 1.04944
# [2500]	training's rmse: 0.598199	valid_1's rmse: 1.04878
# [2600]	training's rmse: 0.589967	valid_1's rmse: 1.04801
# [2700]	training's rmse: 0.582009	valid_1's rmse: 1.04725
# [2800]	training's rmse: 0.574287	valid_1's rmse: 1.04699
# [2900]	training's rmse: 0.566662	valid_1's rmse: 1.04662
# [3000]	training's rmse: 0.559364	valid_1's rmse: 1.04605
# [3100]	training's rmse: 0.552161	valid_1's rmse: 1.04577
# Early stopping, best iteration is:
# [3073]	training's rmse: 0.554205	valid_1's rmse: 1.04567
# Fold 0 rmsle: 1.0456
# --------------FOLDS : 1 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.20009	valid_1's rmse: 1.2467
# [200]	training's rmse: 1.04602	valid_1's rmse: 1.14238
# [300]	training's rmse: 0.982328	valid_1's rmse: 1.11914
# [400]	training's rmse: 0.93868	valid_1's rmse: 1.10688
# [500]	training's rmse: 0.903891	valid_1's rmse: 1.10049
# [600]	training's rmse: 0.873218	valid_1's rmse: 1.09581
# [700]	training's rmse: 0.846992	valid_1's rmse: 1.09213
# [800]	training's rmse: 0.822879	valid_1's rmse: 1.08985
# [900]	training's rmse: 0.800539	valid_1's rmse: 1.08667
# [1000]	training's rmse: 0.780752	valid_1's rmse: 1.08483
# [1100]	training's rmse: 0.762021	valid_1's rmse: 1.08307
# [1200]	training's rmse: 0.744968	valid_1's rmse: 1.08163
# [1300]	training's rmse: 0.728608	valid_1's rmse: 1.08013
# [1400]	training's rmse: 0.713904	valid_1's rmse: 1.07902
# [1500]	training's rmse: 0.699522	valid_1's rmse: 1.07859
# [1600]	training's rmse: 0.686337	valid_1's rmse: 1.07697
# [1700]	training's rmse: 0.673365	valid_1's rmse: 1.07599
# [1800]	training's rmse: 0.661879	valid_1's rmse: 1.07519
# [1900]	training's rmse: 0.650438	valid_1's rmse: 1.07449
# [2000]	training's rmse: 0.63894	valid_1's rmse: 1.07358
# [2100]	training's rmse: 0.628582	valid_1's rmse: 1.07272
# [2200]	training's rmse: 0.618587	valid_1's rmse: 1.07176
# [2300]	training's rmse: 0.608979	valid_1's rmse: 1.07139
# [2400]	training's rmse: 0.599864	valid_1's rmse: 1.07085
# [2500]	training's rmse: 0.590813	valid_1's rmse: 1.07028
# [2600]	training's rmse: 0.581972	valid_1's rmse: 1.06988
# [2700]	training's rmse: 0.574161	valid_1's rmse: 1.06959
# [2800]	training's rmse: 0.566065	valid_1's rmse: 1.06921
# [2900]	training's rmse: 0.558056	valid_1's rmse: 1.06883
# [3000]	training's rmse: 0.550555	valid_1's rmse: 1.06832
# [3100]	training's rmse: 0.543079	valid_1's rmse: 1.06783
# [3200]	training's rmse: 0.535859	valid_1's rmse: 1.06747
# [3300]	training's rmse: 0.529288	valid_1's rmse: 1.06709
# [3400]	training's rmse: 0.523039	valid_1's rmse: 1.06688
# [3500]	training's rmse: 0.516713	valid_1's rmse: 1.06695
# Early stopping, best iteration is:
# [3427]	training's rmse: 0.521119	valid_1's rmse: 1.06679
# Fold 1 rmsle: 1.0668
# --------------FOLDS : 2 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.20726	valid_1's rmse: 1.23535
# [200]	training's rmse: 1.05507	valid_1's rmse: 1.12844
# [300]	training's rmse: 0.991956	valid_1's rmse: 1.10157
# [400]	training's rmse: 0.947715	valid_1's rmse: 1.08761
# [500]	training's rmse: 0.912469	valid_1's rmse: 1.08009
# [600]	training's rmse: 0.882821	valid_1's rmse: 1.07425
# [700]	training's rmse: 0.856809	valid_1's rmse: 1.07035
# [800]	training's rmse: 0.832841	valid_1's rmse: 1.06647
# [900]	training's rmse: 0.811088	valid_1's rmse: 1.06343
# [1000]	training's rmse: 0.790521	valid_1's rmse: 1.06011
# [1100]	training's rmse: 0.771639	valid_1's rmse: 1.05814
# [1200]	training's rmse: 0.75401	valid_1's rmse: 1.05577
# [1300]	training's rmse: 0.737895	valid_1's rmse: 1.0536
# [1400]	training's rmse: 0.722872	valid_1's rmse: 1.05199
# [1500]	training's rmse: 0.708778	valid_1's rmse: 1.05091
# [1600]	training's rmse: 0.695232	valid_1's rmse: 1.04989
# [1700]	training's rmse: 0.682455	valid_1's rmse: 1.04899
# [1800]	training's rmse: 0.67004	valid_1's rmse: 1.04788
# [1900]	training's rmse: 0.658168	valid_1's rmse: 1.04704
# [2000]	training's rmse: 0.646971	valid_1's rmse: 1.04576
# [2100]	training's rmse: 0.636613	valid_1's rmse: 1.04534
# [2200]	training's rmse: 0.626875	valid_1's rmse: 1.04534
# [2300]	training's rmse: 0.617341	valid_1's rmse: 1.04495
# [2400]	training's rmse: 0.607952	valid_1's rmse: 1.04459
# [2500]	training's rmse: 0.59892	valid_1's rmse: 1.04415
# [2600]	training's rmse: 0.590379	valid_1's rmse: 1.04382
# [2700]	training's rmse: 0.582358	valid_1's rmse: 1.04308
# [2800]	training's rmse: 0.574215	valid_1's rmse: 1.04267
# [2900]	training's rmse: 0.566384	valid_1's rmse: 1.04242
# [3000]	training's rmse: 0.558907	valid_1's rmse: 1.04221
# [3100]	training's rmse: 0.551628	valid_1's rmse: 1.04227
# Early stopping, best iteration is:
# [3052]	training's rmse: 0.555082	valid_1's rmse: 1.04209
# Fold 2 rmsle: 1.0420
# --------------FOLDS : 3 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.20001	valid_1's rmse: 1.2552
# [200]	training's rmse: 1.04712	valid_1's rmse: 1.15098
# [300]	training's rmse: 0.982682	valid_1's rmse: 1.12348
# [400]	training's rmse: 0.937946	valid_1's rmse: 1.10947
# [500]	training's rmse: 0.902678	valid_1's rmse: 1.10282
# [600]	training's rmse: 0.872371	valid_1's rmse: 1.09811
# [700]	training's rmse: 0.845889	valid_1's rmse: 1.09496
# [800]	training's rmse: 0.821478	valid_1's rmse: 1.09088
# [900]	training's rmse: 0.79973	valid_1's rmse: 1.08846
# [1000]	training's rmse: 0.778988	valid_1's rmse: 1.08627
# [1100]	training's rmse: 0.760516	valid_1's rmse: 1.08401
# [1200]	training's rmse: 0.743133	valid_1's rmse: 1.08161
# [1300]	training's rmse: 0.726739	valid_1's rmse: 1.08047
# [1400]	training's rmse: 0.711591	valid_1's rmse: 1.07909
# [1500]	training's rmse: 0.697316	valid_1's rmse: 1.07783
# [1600]	training's rmse: 0.683707	valid_1's rmse: 1.07661
# [1700]	training's rmse: 0.670895	valid_1's rmse: 1.07578
# [1800]	training's rmse: 0.658737	valid_1's rmse: 1.0749
# [1900]	training's rmse: 0.647175	valid_1's rmse: 1.0746
# [2000]	training's rmse: 0.636098	valid_1's rmse: 1.07378
# [2100]	training's rmse: 0.625661	valid_1's rmse: 1.07249
# [2200]	training's rmse: 0.615705	valid_1's rmse: 1.07241
# [2300]	training's rmse: 0.606154	valid_1's rmse: 1.07202
# [2400]	training's rmse: 0.596709	valid_1's rmse: 1.07106
# [2500]	training's rmse: 0.588026	valid_1's rmse: 1.07073
# [2600]	training's rmse: 0.579769	valid_1's rmse: 1.07049
# [2700]	training's rmse: 0.571723	valid_1's rmse: 1.07047
# Early stopping, best iteration is:
# [2662]	training's rmse: 0.574826	valid_1's rmse: 1.07042
# Fold 3 rmsle: 1.0704
# --------------FOLDS : 4 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.20408	valid_1's rmse: 1.25316
# [200]	training's rmse: 1.05223	valid_1's rmse: 1.14082
# [300]	training's rmse: 0.98822	valid_1's rmse: 1.11197
# [400]	training's rmse: 0.943975	valid_1's rmse: 1.098
# [500]	training's rmse: 0.908499	valid_1's rmse: 1.09027
# [600]	training's rmse: 0.878082	valid_1's rmse: 1.08508
# [700]	training's rmse: 0.851622	valid_1's rmse: 1.08071
# [800]	training's rmse: 0.827928	valid_1's rmse: 1.07768
# [900]	training's rmse: 0.806206	valid_1's rmse: 1.07475
# [1000]	training's rmse: 0.786341	valid_1's rmse: 1.07184
# [1100]	training's rmse: 0.767186	valid_1's rmse: 1.06972
# [1200]	training's rmse: 0.750113	valid_1's rmse: 1.06748
# [1300]	training's rmse: 0.734198	valid_1's rmse: 1.0654
# [1400]	training's rmse: 0.719104	valid_1's rmse: 1.06413
# [1500]	training's rmse: 0.704327	valid_1's rmse: 1.06237
# [1600]	training's rmse: 0.691018	valid_1's rmse: 1.06142
# [1700]	training's rmse: 0.678151	valid_1's rmse: 1.06057
# [1800]	training's rmse: 0.665523	valid_1's rmse: 1.0599
# [1900]	training's rmse: 0.653825	valid_1's rmse: 1.05951
# [2000]	training's rmse: 0.643283	valid_1's rmse: 1.05904
# [2100]	training's rmse: 0.633023	valid_1's rmse: 1.05795
# [2200]	training's rmse: 0.623144	valid_1's rmse: 1.05727
# [2300]	training's rmse: 0.613624	valid_1's rmse: 1.05693
# [2400]	training's rmse: 0.604331	valid_1's rmse: 1.05666
# [2500]	training's rmse: 0.595551	valid_1's rmse: 1.05655
# Early stopping, best iteration is:
# [2464]	training's rmse: 0.598739	valid_1's rmse: 1.05633
# Fold 4 rmsle: 1.0563
# ALL likes rmsle:  1.0563

# %%
os.makedirs(f"{OUTPUT_DIR}/imp", exist_ok=True)
feature_importance_df[order[:50]].to_csv(f"{OUTPUT_DIR}/imp/importance.csv")

# %%
from make_data import make_oof
oof_df = make_oof(OUTPUT_DIR=OUTPUT_DIR, TARGET=cfg['target'])

# %%
# from score import calc_macro_auc
# score = calc_macro_auc(train_target_df=train_target_df, oof_df=oof_df, order_list=TARGET_IDS)

# %%
sample_sub = pd.read_csv('../../data/atmacup10__sample_submission.csv')

# %%
from make_data import make_sub
sub_df = make_sub(sample_sub=sample_sub, TARGET_NAME=cfg['target'], TRIAL_NAME=TRIAL_NAME, OUTPUT_DIR=OUTPUT_DIR, cv_score=lgbm.score)
# Out:
# QUick Sub
# sh sub.sh output/20210308001939_13_remove_tarenc/pred/pred_likes_1.0563.csv

# %%
sub_df.describe()
# Out:
#               likes
# count  12008.000000
# mean      19.542525
# std       62.818988
# min        0.000000
# 25%        1.024420
# 50%        2.432935
# 75%        6.400599
# max     3090.702420

# %%
from make_fig import make_dist_oof_pred
make_dist_oof_pred(oof_df=oof_df,sub_df=sub_df,OUTPUT_DIR=OUTPUT_DIR)
