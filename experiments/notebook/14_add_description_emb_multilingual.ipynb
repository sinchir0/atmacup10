# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Set Trial Name

# %%
TRIAL_NAME = "14_add_description_emb_multilingual"

import datetime
import pytz
NOW = datetime.datetime.now(pytz.timezone('Asia/Tokyo')).strftime('%Y%m%d%H%M%S')

# %% [markdown]
# # Load yaml

# %%
import yaml
CONFIG_DIR = '../config'
with open(f'{CONFIG_DIR}/run000.yml') as file:
    cfg = yaml.safe_load(file)

import sys
sys.path.append(cfg['SRC_DIR'])
cfg['run_name'] = TRIAL_NAME

# %% [markdown]
# # fix seed

# %%
from util import seed_everything
seed_everything(seed=33, use_torch=False)

# %% [markdown]
# # Make Output Folder

# %%
import os
OUTPUT_DIR = f'../../output/{NOW}_{TRIAL_NAME}'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %% [markdown]
# # Load Model

# %%
import pandas as pd
import numpy as np

sub = pd.read_csv('../../data/atmacup10__sample_submission.csv')
color = pd.read_csv('../../data/color.csv')
historical_person = pd.read_csv('../../data/historical_person.csv')
maker = pd.read_csv('../../data/maker.csv')
material = pd.read_csv('../../data/material.csv')
object_collection = pd.read_csv('../../data/object_collection.csv')
palette = pd.read_csv('../../data/palette.csv')
principal_maker_occupation = pd.read_csv('../../data/principal_maker_occupation.csv')
principal_maker = pd.read_csv('../../data/principal_maker.csv')
production_place = pd.read_csv('../../data/production_place.csv')
technique = pd.read_csv('../../data/technique.csv')
test = pd.read_csv('../../data/test.csv')
test[cfg['target']] = np.nan
train = pd.read_csv('../../data/train.csv')

# %%
train.head(2)
# Out:
#               object_id         art_series_id                  title  \
# 0  0011d6be41612ec9eae3  93c092ba70beab248f31  The Avenue of Birches
# 1  0012765f7a97ccc3e9e9  95c14fb11c54281ad7e0        Struik in bloei
#
#   description                                         long_title  \
# 0         NaN   The Avenue of Birches, Jan Hackaert, 1660 - 1685
# 1         NaN  Struik in bloei, Richard Tepe (attributed to),...
#
#   principal_maker principal_or_first_maker  \
# 0    Jan Hackaert             Jan Hackaert
# 1    Richard Tepe             Richard Tepe
#
#                                  sub_title    copyright_holder  \
# 0  h 66.5cm × w 53.7cm × t 2.5cm × d 4.7cm                 NaN
# 1                        h 165mm × w 223mm  erven Richard Tepe
#
#               more_title acquisition_method     acquisition_date  \
# 0  The Avenue of Birches           purchase  1808-01-01T00:00:00
# 1        Struik in bloei           purchase  2000-01-01T00:00:00
#
#   acquisition_credit_line dating_presenting_date  dating_sorting_date  \
# 0                     NaN            1660 - 1685               1660.0
# 1                     NaN      c. 1900 - c. 1930               1900.0
#
#    dating_period  dating_year_early  dating_year_late  likes
# 0             17             1660.0            1685.0     48
# 1             19             1900.0            1930.0      2

# %%
test.head(2)
# Out:
#               object_id         art_series_id  \
# 0  000405d9a5e3f49fc49d  a2aabd3cc8859f4260ad
# 1  001020bd00b149970f78  5d6a286cc3ab64c2c043
#
#                                                title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#                                          description  \
# 0                                                NaN
# 1  Portret van Philip Ernst (1585-1629), graaf va...
#
#                                           long_title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#               principal_maker    principal_or_first_maker  \
# 0          Bernardus Bruining          Bernardus Bruining
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn
#
#              sub_title copyright_holder  \
# 0    h 167mm × w 108mm              NaN
# 1  h 29.7cm × w 24.1cm              NaN
#
#                                           more_title    acquisition_method  \
# 0  Twee personen voor de Duizendjarige den te Wol...              transfer
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...  nationalization 1795
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1994-01-01T00:00:00                     NaN            1850 - 1900
# 1  1798-09-01T00:00:00                     NaN      c. 1609 - c. 1633
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1850.0             19             1850.0            1900.0
# 1               1609.0             17             1609.0            1633.0
#
#    likes
# 0    NaN
# 1    NaN

# %%
del_non_overlapping_list = [
    # 'object_id',
    'art_series_id',
    #'title',
    #'description',
    #'long_title',
    'principal_maker',
    'principal_or_first_maker',
    #'sub_title',
    'copyright_holder',
    #'more_title',
    'acquisition_method',
    # 'acquisition_date',
    # 'acquisition_credit_line',
    # 'dating_presenting_date',
    # 'dating_sorting_date',
    'dating_period',
    # 'dating_year_early',
    # 'dating_year_late'
]

from util import replace_non_overlap_val_to_missing
train, test = replace_non_overlap_val_to_missing(train,test,columns=del_non_overlapping_list)

# %%
train.head(2)
# Out:
#               object_id art_series_id                  title description  \
# 0  0011d6be41612ec9eae3         other  The Avenue of Birches         NaN
# 1  0012765f7a97ccc3e9e9         other        Struik in bloei         NaN
#
#                                           long_title principal_maker  \
# 0   The Avenue of Birches, Jan Hackaert, 1660 - 1685    Jan Hackaert
# 1  Struik in bloei, Richard Tepe (attributed to),...    Richard Tepe
#
#   principal_or_first_maker                                sub_title  \
# 0             Jan Hackaert  h 66.5cm × w 53.7cm × t 2.5cm × d 4.7cm
# 1             Richard Tepe                        h 165mm × w 223mm
#
#      copyright_holder             more_title acquisition_method  \
# 0             missing  The Avenue of Birches           purchase
# 1  erven Richard Tepe        Struik in bloei           purchase
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1808-01-01T00:00:00                     NaN            1660 - 1685
# 1  2000-01-01T00:00:00                     NaN      c. 1900 - c. 1930
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1660.0             17             1660.0            1685.0
# 1               1900.0             19             1900.0            1930.0
#
#    likes
# 0     48
# 1      2

# %%
test.head(2)
# Out:
#               object_id art_series_id  \
# 0  000405d9a5e3f49fc49d         other
# 1  001020bd00b149970f78         other
#
#                                                title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#                                          description  \
# 0                                                NaN
# 1  Portret van Philip Ernst (1585-1629), graaf va...
#
#                                           long_title  \
# 0  Twee personen voor de Duizendjarige den te Wol...
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...
#
#               principal_maker    principal_or_first_maker  \
# 0          Bernardus Bruining          Bernardus Bruining
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn
#
#              sub_title copyright_holder  \
# 0    h 167mm × w 108mm          missing
# 1  h 29.7cm × w 24.1cm          missing
#
#                                           more_title    acquisition_method  \
# 0  Twee personen voor de Duizendjarige den te Wol...              transfer
# 1  Portrait of Philipp Ernst, Count of Hohenlohe ...  nationalization 1795
#
#       acquisition_date acquisition_credit_line dating_presenting_date  \
# 0  1994-01-01T00:00:00                     NaN            1850 - 1900
# 1  1798-09-01T00:00:00                     NaN      c. 1609 - c. 1633
#
#    dating_sorting_date  dating_period  dating_year_early  dating_year_late  \
# 0               1850.0             19             1850.0            1900.0
# 1               1609.0             17             1609.0            1633.0
#
#    likes
# 0    NaN
# 1    NaN

# %% [markdown]
# # Merge Data

# %%
group = train.groupby('principal_maker')

agg_df = pd.concat([
    group.size().rename('size'), # 著者が何回出てくるか. (value_counts と同じです)
    group['sub_title'].nunique().rename('sub_title_num'), # 著者ごとに何種類の sub_title を持っているか
    group['dating_sorting_date'].agg(['min', 'max', 'mean']), # 著者ごとに描いた年度の最小・最大・平均 (agg に配列を渡すと同時に複数やってくれます)
], axis=1)

agg_df.head()
# Out:
#                  size  sub_title_num     min     max    mean
# principal_maker
# A. Böeseken         5              5  1858.0  1873.0  1865.8
# A. Lutz             1              1  1825.0  1825.0  1825.0
# A. Mansuy           2              2  1860.0  1860.0  1860.0
# A. Nissen           3              1  1860.0  1860.0  1860.0
# A. Roussel          1              1  1905.0  1905.0  1905.0

# %%
train = pd.merge(train, 
         agg_df,
         on='principal_maker', 
         how='left')

test = pd.merge(test, 
         agg_df,
         on='principal_maker', 
         how='left')

# %%
train.columns
# Out:
# Index(['object_id', 'art_series_id', 'title', 'description', 'long_title',
#        'principal_maker', 'principal_or_first_maker', 'sub_title',
#        'copyright_holder', 'more_title', 'acquisition_method',
#        'acquisition_date', 'acquisition_credit_line', 'dating_presenting_date',
#        'dating_sorting_date', 'dating_period', 'dating_year_early',
#        'dating_year_late', 'likes', 'size', 'sub_title_num', 'min', 'max',
#        'mean'],
#       dtype='object')

# %% [markdown]
# # Feature Enginnering

# %%
def create_object_feature(input_df):        
    return input_df['likes'].copy()

create_object_feature(test).head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: likes, dtype: float64

# %%
def create_numeric_feature(input_df):
    use_columns = [
        'dating_period',
        'dating_year_early',
        'dating_year_late'
    ]

    return input_df[use_columns].copy()

create_numeric_feature(train).head(2)
# Out:
#    dating_period  dating_year_early  dating_year_late
# 0             17             1660.0            1685.0
# 1             19             1900.0            1930.0

# %%
def create_categorical_feature(input_df):
    use_columns = [
    'art_series_id',
    'principal_maker',
    'principal_or_first_maker',
    'copyright_holder',
    'acquisition_method',
    ]

    return input_df[use_columns].copy()

create_categorical_feature(train).head(2)
# Out:
#   art_series_id principal_maker principal_or_first_maker    copyright_holder  \
# 0         other    Jan Hackaert             Jan Hackaert             missing
# 1         other    Richard Tepe             Richard Tepe  erven Richard Tepe
#
#   acquisition_method
# 0           purchase
# 1           purchase

# %%
import datetime

def create_acquisition_feature(input_df):
    out_df = pd.DataFrame()
    
    use_columns = [
        'acquisition_date'
    ]
    
    out_df['year'] = pd.to_datetime(input_df['acquisition_date']).dt.year
    out_df['month'] = pd.to_datetime(input_df['acquisition_date']).dt.month
    out_df['dayofweek'] = pd.to_datetime(input_df['acquisition_date']).dt.dayofweek
    out_df['sum_time'] =  10**10 - pd.to_datetime(input_df['acquisition_date']).view('int') // 10**9
    
    return out_df.add_prefix('AcquisitionDate_')

create_acquisition_feature(train).head(2)
# Out:
#    AcquisitionDate_year  AcquisitionDate_month  AcquisitionDate_dayofweek  \
# 0                1808.0                    1.0                        4.0
# 1                2000.0                    1.0                        5.0
#
#    AcquisitionDate_sum_time
# 0               15112288000
# 1                9053315200

# %%
# from util import inf2nan

# def create_principal_maker_info_feature(input_df):
#     '''作者の情報を追加'''
#     out_df = pd.DataFrame()

#     input_df_object_id = input_df['object_id']
    
#     # 作成期間の平均の年を作成
#     train['dating_year_mean'] = (train['dating_year_early'] + train['dating_year_late']) / 2
#     test['dating_year_mean'] = (test['dating_year_early'] + test['dating_year_late']) / 2

#     merge_df = pd.concat([train, test],axis=0).reset_index(drop=True)

#     # 作成期間の平均までに稼いだ良いねの総数、作者の人気度指数
#     out_df['object_id'] = merge_df['object_id']
#     out_df['principal_maker'] = merge_df['principal_maker']
#     out_df['dating_year_mean'] = merge_df['dating_year_mean']
#     out_df['cumsum'] = merge_df.sort_values('dating_year_mean').groupby('principal_maker')['likes'].cumsum()
#     out_df['cumsum_fillnan'] = out_df.sort_values('dating_year_mean').groupby('principal_maker')['cumsum'].ffill()

#     # 作成期間の平均までに出した作品の数
#     tmp_df = pd.DataFrame()
#     tmp_df['object_id'] = train['object_id']
#     tmp_df['cumcount'] = train.sort_values('dating_year_mean').groupby('principal_maker').cumcount()
#     out_df = pd.merge(out_df, tmp_df, on='object_id', how='left')
#     out_df['cumcount_fillnan'] = out_df.sort_values('dating_year_mean').groupby('principal_maker')['cumcount'].ffill()

#     # 作成期間の平均における良いねの作品平均、作者の人気度指数
#     out_df['cumsum_per_cumcount'] = out_df['cumsum_fillnan'] / out_df['cumcount_fillnan']
#     out_df['cumsum_per_cumcount'] = inf2nan(out_df['cumsum_per_cumcount'])
    
#     # anonymousはnanにする
#     anonymous_idx = out_df[out_df['principal_maker'] == 'anonymous'].index
#     out_df.loc[anonymous_idx,['cumsum_fillnan','cumcount_fillnan','cumsum_per_cumcount']] = np.nan
    
#     # filter by id
#     out_df = out_df[out_df['object_id'].isin(input_df_object_id)].reset_index(drop=True)

#     return out_df[['cumsum_fillnan','cumcount_fillnan','cumsum_per_cumcount']].add_prefix('PrincipalMakerInfo_')

# create_principal_maker_info_feature(train).head(2)

# %%
def create_string_length_feature(input_df):
    out_df = pd.DataFrame()

    str_columns = [
        'title', 
        'long_title',
        'sub_title',
        'more_title'
        # and more
    ]

    for c in str_columns:
        out_df[c] = input_df[c].str.len()

    return out_df.add_prefix('StringLength__')

create_string_length_feature(train).head(2)
# Out:
#    StringLength__title  StringLength__long_title  StringLength__sub_title  \
# 0                   21                        48                     39.0
# 1                   15                        64                     17.0
#
#    StringLength__more_title
# 0                      21.0
# 1                      15.0

# %%
def create_count_encoding_feature(input_df):
    use_columns = [
        'acquisition_method',
        'title',
        'principal_maker',
        # and more
    ]

    out_df = pd.DataFrame()
    for column in use_columns:
        vc = train[column].value_counts()
        out_df[column] = input_df[column].map(vc)

    return out_df.add_prefix('CE_')

create_count_encoding_feature(train).head(2)
# Out:
#    CE_acquisition_method  CE_title  CE_principal_maker
# 0                   4253         1                   3
# 1                   4253         1                 180

# %%
def create_one_hot_encoding(input_df):
    use_columns = [
        'acquisition_method',
        'principal_maker'
    ]
    out_df = pd.DataFrame()
    for column in use_columns:

        # あまり巨大な行列にならないよう, 出現回数が 20 回を下回るカテゴリは考慮しない
        vc = train[column].value_counts()
        vc = vc[vc > 20]

        # 明示的に catgories を指定して, input_df によらず列の大きさが等しくなるようにする
        cat = pd.Categorical(input_df[column], categories=vc.index)

        # このタイミングで one-hot 化
        out_i = pd.get_dummies(cat)
        # column が Catgory 型として認識されているので list にして解除する (こうしないと concat でエラーになる)
        out_i.columns = out_i.columns.tolist()
        out_i = out_i.add_prefix(f'{column}=')
        out_df = pd.concat([out_df, out_i], axis=1)
    return out_df

create_one_hot_encoding(train).head(2)
# Out:
#    acquisition_method=purchase  acquisition_method=transfer  \
# 0                            1                            0
# 1                            1                            0
#
#    acquisition_method=gift  acquisition_method=unknown  \
# 0                        0                           0
# 1                        0                           0
#
#    acquisition_method=bequest  acquisition_method=loan  \
# 0                           0                        0
# 1                           0                        0
#
#    acquisition_method=missing  acquisition_method=nationalization 1795  \
# 0                           0                                        0
# 1                           0                                        0
#
#    principal_maker=anonymous  principal_maker=other  ...  \
# 0                          0                      0  ...
# 1                          0                      0  ...
#
#    principal_maker=James Valentine  \
# 0                                0
# 1                                0
#
#    principal_maker=C.M. Ferrier & F. von Martens  principal_maker=Jan Banning  \
# 0                                              0                            0
# 1                                              0                            0
#
#    principal_maker=Cor Jaring  principal_maker=Adolphe Zimmermans  \
# 0                           0                                   0
# 1                           0                                   0
#
#    principal_maker=Wouter Johannes van Troostwijk  \
# 0                                               0
# 1                                               0
#
#    principal_maker=Jan Maurits Quinkhard  \
# 0                                      0
# 1                                      0
#
#    principal_maker=Jean Baptiste August Kessler  \
# 0                                             0
# 1                                             0
#
#    principal_maker=Gerard Edelinck  principal_maker=Augusta Curiel
# 0                                0                               0
# 1                                0                               0
#
# [2 rows x 98 columns]

# %%
import re

#  h 166mm × w 78/54mm

def get_h_from_subtitle(text:str):
    match_cm = re.search(r'h \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'h \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100

def get_w_from_subtitle(text:str):
    match_cm = re.search(r'w \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'w \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        elif match_mm.group()[2:-2] == '78/54':
            return float(78)
        else:
            return float(match_mm.group()[2:-2])/100    

def get_t_from_subtitle(text:str):
    match_cm = re.search(r't \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r't \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100   

def get_d_from_subtitle(text:str):
    match_cm = re.search(r'd \S+cm', text)
    if match_cm:
        if match_cm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_cm.group()[2:-2])

    match_mm = re.search(r'd \S+mm', text)
    if match_mm:
        if match_mm.group()[2:-2] == '':
            return np.nan
        else:
            return float(match_mm.group()[2:-2])/100   
        
def create_subtitle_info(input_df):
    out_df = pd.DataFrame()
     
    out_df['subtitle_h'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_h_from_subtitle(x))
    out_df['subtitle_w'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_w_from_subtitle(x))
    out_df['subtitle_t'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_t_from_subtitle(x))
    out_df['subtitle_d'] = input_df['sub_title'].fillna('missing').apply(lambda x : get_d_from_subtitle(x))
    
    out_df['area'] = out_df['subtitle_h'] * out_df['subtitle_w']
    out_df['volume'] = out_df['subtitle_h'] * out_df['subtitle_w'] * out_df['subtitle_t']

    return out_df

create_subtitle_info(test).head(2)
# Out:
#    subtitle_h  subtitle_w  subtitle_t  subtitle_d      area  volume
# 0        1.67        1.08         NaN         NaN    1.8036     NaN
# 1       29.70       24.10         NaN         NaN  715.7700     NaN

# %%
# # train_emb_npy = np.load('../../extract_data/train_word_emb.npy')
# # test_emb_npy = np.load('../../extract_data/test_word_emb.npy')

# train_emb_npy = np.load('../../extract_data/train_description_emb_multilingual.npy')
# test_emb_npy = np.load('../../extract_data/test_description_emb_multilingual.npy')

# train_emb_df = pd.concat([train['object_id'], pd.DataFrame(train_emb_npy)],axis=1)
# test_emb_df = pd.concat([test['object_id'], pd.DataFrame(test_emb_npy)],axis=1)

# all_df = pd.concat([train_emb_df,test_emb_df],axis=0).reset_index(drop=True)

# all_df.to_pickle('../../extract_data/all_description_emb_multilingual.pkl')

# %%
def create_word_emb(input_df):
    out_df = pd.DataFrame()
    
    all_emb_df = pd.read_pickle('../../extract_data/all_description_emb_multilingual.pkl')
    
    input_word_emb = pd.merge(input_df['object_id'], all_emb_df, on='object_id', how='left')
    return input_word_emb[[num for num in range(768)]].add_prefix('DescriptionEmb_')

create_word_emb(test).tail(2)
# Out:
#        DescriptionEmb_0  DescriptionEmb_1  DescriptionEmb_2  DescriptionEmb_3  \
# 12006          0.436396         -0.335005          0.667921          0.318818
# 12007          0.032771         -0.072671         -0.102609          0.166501
#
#        DescriptionEmb_4  DescriptionEmb_5  DescriptionEmb_6  DescriptionEmb_7  \
# 12006          0.031258         -0.095407         -0.153339         -0.259155
# 12007          0.142990          0.144593          0.230255          0.101836
#
#        DescriptionEmb_8  DescriptionEmb_9  ...  DescriptionEmb_758  \
# 12006          0.369516          0.258500  ...           -0.165603
# 12007         -0.083562          0.026109  ...            0.081963
#
#        DescriptionEmb_759  DescriptionEmb_760  DescriptionEmb_761  \
# 12006           -0.289044           -0.589709           -0.281333
# 12007           -0.224610           -0.059094           -0.125912
#
#        DescriptionEmb_762  DescriptionEmb_763  DescriptionEmb_764  \
# 12006            0.260206            0.284698            0.160815
# 12007            0.153219            0.281579            0.073063
#
#        DescriptionEmb_765  DescriptionEmb_766  DescriptionEmb_767
# 12006            0.512557           -0.175026            0.298428
# 12007            0.090924            0.033375           -0.077214
#
# [2 rows x 768 columns]

# %%
# https://github.com/nyk510/vivid/blob/master/vivid/utils.py
from contextlib import contextmanager
from time import time

class Timer:
    def __init__(self, logger=None, format_str='{:.3f}[s]', prefix=None, suffix=None, sep=' '):

        if prefix: format_str = str(prefix) + sep + format_str
        if suffix: format_str = format_str + sep + str(suffix)
        self.format_str = format_str
        self.logger = logger
        self.start = None
        self.end = None

    @property
    def duration(self):
        if self.end is None:
            return 0
        return self.end - self.start

    def __enter__(self):
        self.start = time()

    def __exit__(self, exc_type, exc_val, exc_tb):
        self.end = time()
        out_str = self.format_str.format(self.duration)
        if self.logger:
            self.logger.info(out_str)
        else:
            print(out_str)

# %%
from tqdm import tqdm

def to_feature(input_df):
    """input_df を特徴量行列に変換した新しいデータフレームを返す.
    """

    processors = [
        create_object_feature,
        create_numeric_feature,
        create_categorical_feature,
        create_acquisition_feature,
        # create_principal_maker_info_feature,
        create_string_length_feature,
        create_count_encoding_feature,
        create_one_hot_encoding,
        create_subtitle_info,
        create_word_emb
    ]

    out_df = pd.DataFrame()

    for func in tqdm(processors, total=len(processors)):
        with Timer(prefix='create' + func.__name__ + ' '):
            _df = func(input_df)
        # 長さが等しいことをチェック (ずれている場合, func の実装がおかしい)
        assert len(_df) == len(input_df), func.__name__
        out_df = pd.concat([out_df, _df], axis=1)

    return out_df

train_feat= to_feature(train)
test_feat = to_feature(test)

train = train_feat.copy()
test = test_feat.copy()
# Out:
#  89%|████████▉ | 8/9 [00:00<00:00, 45.92it/s]
# createcreate_object_feature  0.001[s]
# createcreate_numeric_feature  0.001[s]
# createcreate_categorical_feature  0.002[s]
# createcreate_acquisition_feature  0.026[s]
# createcreate_string_length_feature  0.016[s]
# createcreate_count_encoding_feature  0.011[s]
# createcreate_one_hot_encoding  0.010[s]
# createcreate_subtitle_info  0.081[s]
# 100%|██████████| 9/9 [00:00<00:00, 23.01it/s]
#  89%|████████▉ | 8/9 [00:00<00:00, 47.69it/s]
# createcreate_word_emb  0.194[s]
# createcreate_object_feature  0.000[s]
# createcreate_numeric_feature  0.002[s]
# createcreate_categorical_feature  0.002[s]
# createcreate_acquisition_feature  0.015[s]
# createcreate_string_length_feature  0.018[s]
# createcreate_count_encoding_feature  0.012[s]
# createcreate_one_hot_encoding  0.009[s]
# createcreate_subtitle_info  0.079[s]
# 100%|██████████| 9/9 [00:00<00:00, 22.32it/s]
# createcreate_word_emb  0.209[s]

# %%
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %% [markdown]
# # train

# %%
train.isnull().sum()
# Out:
# likes                  0
# dating_period          0
# dating_year_early     10
# dating_year_late      38
# art_series_id          0
#                       ..
# DescriptionEmb_763     0
# DescriptionEmb_764     0
# DescriptionEmb_765     0
# DescriptionEmb_766     0
# DescriptionEmb_767     0
# Length: 892, dtype: int64

# %%
test.head(2)
# Out:
#    likes  dating_period  dating_year_early  dating_year_late art_series_id  \
# 0    NaN             19             1850.0            1900.0         other
# 1    NaN             17             1609.0            1633.0         other
#
#               principal_maker    principal_or_first_maker copyright_holder  \
# 0          Bernardus Bruining          Bernardus Bruining          missing
# 1  Jan Antonisz van Ravesteyn  Jan Antonisz van Ravesteyn          missing
#
#      acquisition_method  AcquisitionDate_year  ...  DescriptionEmb_758  \
# 0              transfer                1994.0  ...           -0.165603
# 1  nationalization 1795                1798.0  ...            0.046266
#
#    DescriptionEmb_759  DescriptionEmb_760  DescriptionEmb_761  \
# 0           -0.289044           -0.589709           -0.281333
# 1           -0.160513           -0.231780           -0.166865
#
#    DescriptionEmb_762  DescriptionEmb_763  DescriptionEmb_764  \
# 0            0.260206            0.284698            0.160815
# 1           -0.095945           -0.102381            0.022292
#
#    DescriptionEmb_765  DescriptionEmb_766  DescriptionEmb_767
# 0            0.512557           -0.175026            0.298428
# 1            0.185468           -0.100122           -0.122960
#
# [2 rows x 892 columns]

# %% [markdown]
# # reduce mem usage

# %%
# from util import reduce_mem_usage
# train_feat_df = reduce_mem_usage(train_feat_df)
# test_feat_df = reduce_mem_usage(test_feat_df)

# %% [markdown]
# # Lable Encoding

# %%
cat_col = train.select_dtypes('O').columns.tolist()

# %%
from fe import label_encode
train, test = label_encode(train, test, cat_col)

# %%
train.dtypes
# Out:
# likes                   int64
# dating_period           int64
# dating_year_early     float64
# dating_year_late      float64
# art_series_id           int64
#                        ...
# DescriptionEmb_763    float32
# DescriptionEmb_764    float32
# DescriptionEmb_765    float32
# DescriptionEmb_766    float32
# DescriptionEmb_767    float32
# Length: 892, dtype: object

# %% [markdown]
# # add fold

# %%
from fold import add_fold_bin_skf
train = add_fold_bin_skf(train, train[cfg['target']], fold_num=5, bins=[0,1,10,100,1000, 27392])

# %% [markdown]
# # Target Encoding

# %%
train['dating_period']
# Out:
# 0        17
# 1        19
# 2        19
# 3        19
# 4        19
#          ..
# 12021    19
# 12022    18
# 12023    18
# 12024    17
# 12025    15
# Name: dating_period, Length: 12026, dtype: int64

# %%
target_enc_list = [
    # 'art_series_id',
    'principal_maker',
    'principal_or_first_maker',
    'copyright_holder',
    'acquisition_method',
    'dating_period'
]

from fe import target_encoding
train, test = target_encoding(train, 
                              test, 
                              target = cfg['target'], 
                              target_enc_list = target_enc_list, 
                              fold_num = cfg['fold_num']
                             )
# Out:
# principal_maker
# principal_or_first_maker
# copyright_holder
# acquisition_method
# dating_period

# %% [markdown]
# # Make Model

# %%
use_col = train.columns.tolist()
use_col.remove('fold')
use_col.remove(cfg['target'])

# %%
use_col
# Out:
# ['dating_period',
#  'dating_year_early',
#  'dating_year_late',
#  'art_series_id',
#  'principal_maker',
#  'principal_or_first_maker',
#  'copyright_holder',
#  'acquisition_method',
#  'AcquisitionDate_year',
#  'AcquisitionDate_month',
#  'AcquisitionDate_dayofweek',
#  'AcquisitionDate_sum_time',
#  'StringLength__title',
#  'StringLength__long_title',
#  'StringLength__sub_title',
#  'StringLength__more_title',
#  'CE_acquisition_method',
#  'CE_title',
#  'CE_principal_maker',
#  'acquisition_method=purchase',
#  'acquisition_method=transfer',
#  'acquisition_method=gift',
#  'acquisition_method=unknown',
#  'acquisition_method=bequest',
#  'acquisition_method=loan',
#  'acquisition_method=missing',
#  'acquisition_method=nationalization 1795',
#  'principal_maker=anonymous',
#  'principal_maker=other',
#  'principal_maker=Johann Sadeler (I)',
#  'principal_maker=Bernard Picart',
#  'principal_maker=Richard Tepe',
#  'principal_maker=anoniem (Monumentenzorg)',
#  'principal_maker=Jan Luyken',
#  'principal_maker=Raphaël Sadeler (I)',
#  'principal_maker=Woodbury & Page',
#  'principal_maker=Romeyn de Hooghe',
#  'principal_maker=Aegidius Sadeler',
#  'principal_maker=Giorgio Sommer',
#  'principal_maker=Willem Diepraam',
#  'principal_maker=Jacob Olie jr.',
#  'principal_maker=Geldolph Adriaan Kessler',
#  'principal_maker=L. Heldring',
#  'principal_maker=Abraham Rademaker',
#  'principal_maker=Hermanus Jan Hendrik van Rijkelijkhuysen',
#  'principal_maker=Crispijn van de Passe (I)',
#  'principal_maker=Jan Harmensz. Muller',
#  'principal_maker=Johanna Margaretha Piek',
#  'principal_maker=Cornelis Galle (I)',
#  'principal_maker=Jacob de Gheyn (II)',
#  'principal_maker=Cornelis Ploos van Amstel',
#  'principal_maker=Théodore van Lelyveld',
#  'principal_maker=Jacob van der Schley',
#  'principal_maker=Daniël Veelwaard (I)',
#  'principal_maker=Jan Frederik Christiaan Reckleben',
#  'principal_maker=Paulus Pontius',
#  'principal_maker=Albert Greiner',
#  'principal_maker=Hendrick Goltzius',
#  'principal_maker=Henry Pauw van Wieldrecht',
#  'principal_maker=Francis Frith',
#  'principal_maker=Heinrich Aldegrever',
#  'principal_maker=Theodoor Koning',
#  'principal_maker=Roelant Roghman',
#  'principal_maker=Adolphe Burdet',
#  'principal_maker=Jacques Lalaing',
#  'principal_maker=Bonfils',
#  'principal_maker=Juan Laurent',
#  'principal_maker=G. Dangereux',
#  'principal_maker=Philip Henry Delamotte',
#  'principal_maker=Fratelli Alinari',
#  'principal_maker=Henry W. Taunt',
#  'principal_maker=Atelier Kurkdjian',
#  'principal_maker=Isidore Kinsbergen',
#  'principal_maker=Charles Rochussen',
#  'principal_maker=Johann Heinrich Maria Hubert Rennefeld',
#  'principal_maker=Carl Cristiaan Fuchs',
#  'principal_maker=Paul Güssfeldt',
#  'principal_maker=Samuel Bourne',
#  'principal_maker=Eberhard Cornelis Rahms',
#  'principal_maker=Caspar Luyken',
#  'principal_maker=Jan van de Velde (II)',
#  'principal_maker=Waldemar Titzenthaler',
#  'principal_maker=Gabriel Huquier',
#  'principal_maker=Jozef Van Ruyssevelt',
#  'principal_maker=George Hendrik Breitner',
#  'principal_maker=Jean Baptiste Vanmour',
#  'principal_maker=Joost van Geel',
#  'principal_maker=Theodoor van Thulden',
#  'principal_maker=Giacomo Brogi',
#  'principal_maker=Dirck Volckertsz. Coornhert',
#  'principal_maker=Hendrik Roosing',
#  'principal_maker=Schelte Adamsz. Bolswert',
#  'principal_maker=James Higson',
#  'principal_maker=Christiaan Benjamin Nieuwenhuis',
#  'principal_maker=Herman Salzwedel',
#  'principal_maker=Gustave Eugène Chauffourier',
#  'principal_maker=Charles Thurston Thompson',
#  'principal_maker=O. Hisgen & Co.',
#  'principal_maker=Maurits Verveer',
#  'principal_maker=Heinrich Ernst & Co',
#  'principal_maker=Boëtius Adamsz. Bolswert',
#  'principal_maker=Arnoud van Halen',
#  'principal_maker=Jan Goedeljee',
#  'principal_maker=Kornelis Willem Schorteldoek',
#  'principal_maker=Simon Fokke',
#  'principal_maker=Ohannes Kurkdjian',
#  'principal_maker=Rembrandt van Rijn',
#  'principal_maker=James Valentine',
#  'principal_maker=C.M. Ferrier & F. von Martens',
#  'principal_maker=Jan Banning',
#  'principal_maker=Cor Jaring',
#  'principal_maker=Adolphe Zimmermans',
#  'principal_maker=Wouter Johannes van Troostwijk',
#  'principal_maker=Jan Maurits Quinkhard',
#  'principal_maker=Jean Baptiste August Kessler',
#  'principal_maker=Gerard Edelinck',
#  'principal_maker=Augusta Curiel',
#  'subtitle_h',
#  'subtitle_w',
#  'subtitle_t',
#  'subtitle_d',
#  'area',
#  'volume',
#  'DescriptionEmb_0',
#  'DescriptionEmb_1',
#  'DescriptionEmb_2',
#  'DescriptionEmb_3',
#  'DescriptionEmb_4',
#  'DescriptionEmb_5',
#  'DescriptionEmb_6',
#  'DescriptionEmb_7',
#  'DescriptionEmb_8',
#  'DescriptionEmb_9',
#  'DescriptionEmb_10',
#  'DescriptionEmb_11',
#  'DescriptionEmb_12',
#  'DescriptionEmb_13',
#  'DescriptionEmb_14',
#  'DescriptionEmb_15',
#  'DescriptionEmb_16',
#  'DescriptionEmb_17',
#  'DescriptionEmb_18',
#  'DescriptionEmb_19',
#  'DescriptionEmb_20',
#  'DescriptionEmb_21',
#  'DescriptionEmb_22',
#  'DescriptionEmb_23',
#  'DescriptionEmb_24',
#  'DescriptionEmb_25',
#  'DescriptionEmb_26',
#  'DescriptionEmb_27',
#  'DescriptionEmb_28',
#  'DescriptionEmb_29',
#  'DescriptionEmb_30',
#  'DescriptionEmb_31',
#  'DescriptionEmb_32',
#  'DescriptionEmb_33',
#  'DescriptionEmb_34',
#  'DescriptionEmb_35',
#  'DescriptionEmb_36',
#  'DescriptionEmb_37',
#  'DescriptionEmb_38',
#  'DescriptionEmb_39',
#  'DescriptionEmb_40',
#  'DescriptionEmb_41',
#  'DescriptionEmb_42',
#  'DescriptionEmb_43',
#  'DescriptionEmb_44',
#  'DescriptionEmb_45',
#  'DescriptionEmb_46',
#  'DescriptionEmb_47',
#  'DescriptionEmb_48',
#  'DescriptionEmb_49',
#  'DescriptionEmb_50',
#  'DescriptionEmb_51',
#  'DescriptionEmb_52',
#  'DescriptionEmb_53',
#  'DescriptionEmb_54',
#  'DescriptionEmb_55',
#  'DescriptionEmb_56',
#  'DescriptionEmb_57',
#  'DescriptionEmb_58',
#  'DescriptionEmb_59',
#  'DescriptionEmb_60',
#  'DescriptionEmb_61',
#  'DescriptionEmb_62',
#  'DescriptionEmb_63',
#  'DescriptionEmb_64',
#  'DescriptionEmb_65',
#  'DescriptionEmb_66',
#  'DescriptionEmb_67',
#  'DescriptionEmb_68',
#  'DescriptionEmb_69',
#  'DescriptionEmb_70',
#  'DescriptionEmb_71',
#  'DescriptionEmb_72',
#  'DescriptionEmb_73',
#  'DescriptionEmb_74',
#  'DescriptionEmb_75',
#  'DescriptionEmb_76',
#  'DescriptionEmb_77',
#  'DescriptionEmb_78',
#  'DescriptionEmb_79',
#  'DescriptionEmb_80',
#  'DescriptionEmb_81',
#  'DescriptionEmb_82',
#  'DescriptionEmb_83',
#  'DescriptionEmb_84',
#  'DescriptionEmb_85',
#  'DescriptionEmb_86',
#  'DescriptionEmb_87',
#  'DescriptionEmb_88',
#  'DescriptionEmb_89',
#  'DescriptionEmb_90',
#  'DescriptionEmb_91',
#  'DescriptionEmb_92',
#  'DescriptionEmb_93',
#  'DescriptionEmb_94',
#  'DescriptionEmb_95',
#  'DescriptionEmb_96',
#  'DescriptionEmb_97',
#  'DescriptionEmb_98',
#  'DescriptionEmb_99',
#  'DescriptionEmb_100',
#  'DescriptionEmb_101',
#  'DescriptionEmb_102',
#  'DescriptionEmb_103',
#  'DescriptionEmb_104',
#  'DescriptionEmb_105',
#  'DescriptionEmb_106',
#  'DescriptionEmb_107',
#  'DescriptionEmb_108',
#  'DescriptionEmb_109',
#  'DescriptionEmb_110',
#  'DescriptionEmb_111',
#  'DescriptionEmb_112',
#  'DescriptionEmb_113',
#  'DescriptionEmb_114',
#  'DescriptionEmb_115',
#  'DescriptionEmb_116',
#  'DescriptionEmb_117',
#  'DescriptionEmb_118',
#  'DescriptionEmb_119',
#  'DescriptionEmb_120',
#  'DescriptionEmb_121',
#  'DescriptionEmb_122',
#  'DescriptionEmb_123',
#  'DescriptionEmb_124',
#  'DescriptionEmb_125',
#  'DescriptionEmb_126',
#  'DescriptionEmb_127',
#  'DescriptionEmb_128',
#  'DescriptionEmb_129',
#  'DescriptionEmb_130',
#  'DescriptionEmb_131',
#  'DescriptionEmb_132',
#  'DescriptionEmb_133',
#  'DescriptionEmb_134',
#  'DescriptionEmb_135',
#  'DescriptionEmb_136',
#  'DescriptionEmb_137',
#  'DescriptionEmb_138',
#  'DescriptionEmb_139',
#  'DescriptionEmb_140',
#  'DescriptionEmb_141',
#  'DescriptionEmb_142',
#  'DescriptionEmb_143',
#  'DescriptionEmb_144',
#  'DescriptionEmb_145',
#  'DescriptionEmb_146',
#  'DescriptionEmb_147',
#  'DescriptionEmb_148',
#  'DescriptionEmb_149',
#  'DescriptionEmb_150',
#  'DescriptionEmb_151',
#  'DescriptionEmb_152',
#  'DescriptionEmb_153',
#  'DescriptionEmb_154',
#  'DescriptionEmb_155',
#  'DescriptionEmb_156',
#  'DescriptionEmb_157',
#  'DescriptionEmb_158',
#  'DescriptionEmb_159',
#  'DescriptionEmb_160',
#  'DescriptionEmb_161',
#  'DescriptionEmb_162',
#  'DescriptionEmb_163',
#  'DescriptionEmb_164',
#  'DescriptionEmb_165',
#  'DescriptionEmb_166',
#  'DescriptionEmb_167',
#  'DescriptionEmb_168',
#  'DescriptionEmb_169',
#  'DescriptionEmb_170',
#  'DescriptionEmb_171',
#  'DescriptionEmb_172',
#  'DescriptionEmb_173',
#  'DescriptionEmb_174',
#  'DescriptionEmb_175',
#  'DescriptionEmb_176',
#  'DescriptionEmb_177',
#  'DescriptionEmb_178',
#  'DescriptionEmb_179',
#  'DescriptionEmb_180',
#  'DescriptionEmb_181',
#  'DescriptionEmb_182',
#  'DescriptionEmb_183',
#  'DescriptionEmb_184',
#  'DescriptionEmb_185',
#  'DescriptionEmb_186',
#  'DescriptionEmb_187',
#  'DescriptionEmb_188',
#  'DescriptionEmb_189',
#  'DescriptionEmb_190',
#  'DescriptionEmb_191',
#  'DescriptionEmb_192',
#  'DescriptionEmb_193',
#  'DescriptionEmb_194',
#  'DescriptionEmb_195',
#  'DescriptionEmb_196',
#  'DescriptionEmb_197',
#  'DescriptionEmb_198',
#  'DescriptionEmb_199',
#  'DescriptionEmb_200',
#  'DescriptionEmb_201',
#  'DescriptionEmb_202',
#  'DescriptionEmb_203',
#  'DescriptionEmb_204',
#  'DescriptionEmb_205',
#  'DescriptionEmb_206',
#  'DescriptionEmb_207',
#  'DescriptionEmb_208',
#  'DescriptionEmb_209',
#  'DescriptionEmb_210',
#  'DescriptionEmb_211',
#  'DescriptionEmb_212',
#  'DescriptionEmb_213',
#  'DescriptionEmb_214',
#  'DescriptionEmb_215',
#  'DescriptionEmb_216',
#  'DescriptionEmb_217',
#  'DescriptionEmb_218',
#  'DescriptionEmb_219',
#  'DescriptionEmb_220',
#  'DescriptionEmb_221',
#  'DescriptionEmb_222',
#  'DescriptionEmb_223',
#  'DescriptionEmb_224',
#  'DescriptionEmb_225',
#  'DescriptionEmb_226',
#  'DescriptionEmb_227',
#  'DescriptionEmb_228',
#  'DescriptionEmb_229',
#  'DescriptionEmb_230',
#  'DescriptionEmb_231',
#  'DescriptionEmb_232',
#  'DescriptionEmb_233',
#  'DescriptionEmb_234',
#  'DescriptionEmb_235',
#  'DescriptionEmb_236',
#  'DescriptionEmb_237',
#  'DescriptionEmb_238',
#  'DescriptionEmb_239',
#  'DescriptionEmb_240',
#  'DescriptionEmb_241',
#  'DescriptionEmb_242',
#  'DescriptionEmb_243',
#  'DescriptionEmb_244',
#  'DescriptionEmb_245',
#  'DescriptionEmb_246',
#  'DescriptionEmb_247',
#  'DescriptionEmb_248',
#  'DescriptionEmb_249',
#  'DescriptionEmb_250',
#  'DescriptionEmb_251',
#  'DescriptionEmb_252',
#  'DescriptionEmb_253',
#  'DescriptionEmb_254',
#  'DescriptionEmb_255',
#  'DescriptionEmb_256',
#  'DescriptionEmb_257',
#  'DescriptionEmb_258',
#  'DescriptionEmb_259',
#  'DescriptionEmb_260',
#  'DescriptionEmb_261',
#  'DescriptionEmb_262',
#  'DescriptionEmb_263',
#  'DescriptionEmb_264',
#  'DescriptionEmb_265',
#  'DescriptionEmb_266',
#  'DescriptionEmb_267',
#  'DescriptionEmb_268',
#  'DescriptionEmb_269',
#  'DescriptionEmb_270',
#  'DescriptionEmb_271',
#  'DescriptionEmb_272',
#  'DescriptionEmb_273',
#  'DescriptionEmb_274',
#  'DescriptionEmb_275',
#  'DescriptionEmb_276',
#  'DescriptionEmb_277',
#  'DescriptionEmb_278',
#  'DescriptionEmb_279',
#  'DescriptionEmb_280',
#  'DescriptionEmb_281',
#  'DescriptionEmb_282',
#  'DescriptionEmb_283',
#  'DescriptionEmb_284',
#  'DescriptionEmb_285',
#  'DescriptionEmb_286',
#  'DescriptionEmb_287',
#  'DescriptionEmb_288',
#  'DescriptionEmb_289',
#  'DescriptionEmb_290',
#  'DescriptionEmb_291',
#  'DescriptionEmb_292',
#  'DescriptionEmb_293',
#  'DescriptionEmb_294',
#  'DescriptionEmb_295',
#  'DescriptionEmb_296',
#  'DescriptionEmb_297',
#  'DescriptionEmb_298',
#  'DescriptionEmb_299',
#  'DescriptionEmb_300',
#  'DescriptionEmb_301',
#  'DescriptionEmb_302',
#  'DescriptionEmb_303',
#  'DescriptionEmb_304',
#  'DescriptionEmb_305',
#  'DescriptionEmb_306',
#  'DescriptionEmb_307',
#  'DescriptionEmb_308',
#  'DescriptionEmb_309',
#  'DescriptionEmb_310',
#  'DescriptionEmb_311',
#  'DescriptionEmb_312',
#  'DescriptionEmb_313',
#  'DescriptionEmb_314',
#  'DescriptionEmb_315',
#  'DescriptionEmb_316',
#  'DescriptionEmb_317',
#  'DescriptionEmb_318',
#  'DescriptionEmb_319',
#  'DescriptionEmb_320',
#  'DescriptionEmb_321',
#  'DescriptionEmb_322',
#  'DescriptionEmb_323',
#  'DescriptionEmb_324',
#  'DescriptionEmb_325',
#  'DescriptionEmb_326',
#  'DescriptionEmb_327',
#  'DescriptionEmb_328',
#  'DescriptionEmb_329',
#  'DescriptionEmb_330',
#  'DescriptionEmb_331',
#  'DescriptionEmb_332',
#  'DescriptionEmb_333',
#  'DescriptionEmb_334',
#  'DescriptionEmb_335',
#  'DescriptionEmb_336',
#  'DescriptionEmb_337',
#  'DescriptionEmb_338',
#  'DescriptionEmb_339',
#  'DescriptionEmb_340',
#  'DescriptionEmb_341',
#  'DescriptionEmb_342',
#  'DescriptionEmb_343',
#  'DescriptionEmb_344',
#  'DescriptionEmb_345',
#  'DescriptionEmb_346',
#  'DescriptionEmb_347',
#  'DescriptionEmb_348',
#  'DescriptionEmb_349',
#  'DescriptionEmb_350',
#  'DescriptionEmb_351',
#  'DescriptionEmb_352',
#  'DescriptionEmb_353',
#  'DescriptionEmb_354',
#  'DescriptionEmb_355',
#  'DescriptionEmb_356',
#  'DescriptionEmb_357',
#  'DescriptionEmb_358',
#  'DescriptionEmb_359',
#  'DescriptionEmb_360',
#  'DescriptionEmb_361',
#  'DescriptionEmb_362',
#  'DescriptionEmb_363',
#  'DescriptionEmb_364',
#  'DescriptionEmb_365',
#  'DescriptionEmb_366',
#  'DescriptionEmb_367',
#  'DescriptionEmb_368',
#  'DescriptionEmb_369',
#  'DescriptionEmb_370',
#  'DescriptionEmb_371',
#  'DescriptionEmb_372',
#  'DescriptionEmb_373',
#  'DescriptionEmb_374',
#  'DescriptionEmb_375',
#  'DescriptionEmb_376',
#  'DescriptionEmb_377',
#  'DescriptionEmb_378',
#  'DescriptionEmb_379',
#  'DescriptionEmb_380',
#  'DescriptionEmb_381',
#  'DescriptionEmb_382',
#  'DescriptionEmb_383',
#  'DescriptionEmb_384',
#  'DescriptionEmb_385',
#  'DescriptionEmb_386',
#  'DescriptionEmb_387',
#  'DescriptionEmb_388',
#  'DescriptionEmb_389',
#  'DescriptionEmb_390',
#  'DescriptionEmb_391',
#  'DescriptionEmb_392',
#  'DescriptionEmb_393',
#  'DescriptionEmb_394',
#  'DescriptionEmb_395',
#  'DescriptionEmb_396',
#  'DescriptionEmb_397',
#  'DescriptionEmb_398',
#  'DescriptionEmb_399',
#  'DescriptionEmb_400',
#  'DescriptionEmb_401',
#  'DescriptionEmb_402',
#  'DescriptionEmb_403',
#  'DescriptionEmb_404',
#  'DescriptionEmb_405',
#  'DescriptionEmb_406',
#  'DescriptionEmb_407',
#  'DescriptionEmb_408',
#  'DescriptionEmb_409',
#  'DescriptionEmb_410',
#  'DescriptionEmb_411',
#  'DescriptionEmb_412',
#  'DescriptionEmb_413',
#  'DescriptionEmb_414',
#  'DescriptionEmb_415',
#  'DescriptionEmb_416',
#  'DescriptionEmb_417',
#  'DescriptionEmb_418',
#  'DescriptionEmb_419',
#  'DescriptionEmb_420',
#  'DescriptionEmb_421',
#  'DescriptionEmb_422',
#  'DescriptionEmb_423',
#  'DescriptionEmb_424',
#  'DescriptionEmb_425',
#  'DescriptionEmb_426',
#  'DescriptionEmb_427',
#  'DescriptionEmb_428',
#  'DescriptionEmb_429',
#  'DescriptionEmb_430',
#  'DescriptionEmb_431',
#  'DescriptionEmb_432',
#  'DescriptionEmb_433',
#  'DescriptionEmb_434',
#  'DescriptionEmb_435',
#  'DescriptionEmb_436',
#  'DescriptionEmb_437',
#  'DescriptionEmb_438',
#  'DescriptionEmb_439',
#  'DescriptionEmb_440',
#  'DescriptionEmb_441',
#  'DescriptionEmb_442',
#  'DescriptionEmb_443',
#  'DescriptionEmb_444',
#  'DescriptionEmb_445',
#  'DescriptionEmb_446',
#  'DescriptionEmb_447',
#  'DescriptionEmb_448',
#  'DescriptionEmb_449',
#  'DescriptionEmb_450',
#  'DescriptionEmb_451',
#  'DescriptionEmb_452',
#  'DescriptionEmb_453',
#  'DescriptionEmb_454',
#  'DescriptionEmb_455',
#  'DescriptionEmb_456',
#  'DescriptionEmb_457',
#  'DescriptionEmb_458',
#  'DescriptionEmb_459',
#  'DescriptionEmb_460',
#  'DescriptionEmb_461',
#  'DescriptionEmb_462',
#  'DescriptionEmb_463',
#  'DescriptionEmb_464',
#  'DescriptionEmb_465',
#  'DescriptionEmb_466',
#  'DescriptionEmb_467',
#  'DescriptionEmb_468',
#  'DescriptionEmb_469',
#  'DescriptionEmb_470',
#  'DescriptionEmb_471',
#  'DescriptionEmb_472',
#  'DescriptionEmb_473',
#  'DescriptionEmb_474',
#  'DescriptionEmb_475',
#  'DescriptionEmb_476',
#  'DescriptionEmb_477',
#  'DescriptionEmb_478',
#  'DescriptionEmb_479',
#  'DescriptionEmb_480',
#  'DescriptionEmb_481',
#  'DescriptionEmb_482',
#  'DescriptionEmb_483',
#  'DescriptionEmb_484',
#  'DescriptionEmb_485',
#  'DescriptionEmb_486',
#  'DescriptionEmb_487',
#  'DescriptionEmb_488',
#  'DescriptionEmb_489',
#  'DescriptionEmb_490',
#  'DescriptionEmb_491',
#  'DescriptionEmb_492',
#  'DescriptionEmb_493',
#  'DescriptionEmb_494',
#  'DescriptionEmb_495',
#  'DescriptionEmb_496',
#  'DescriptionEmb_497',
#  'DescriptionEmb_498',
#  'DescriptionEmb_499',
#  'DescriptionEmb_500',
#  'DescriptionEmb_501',
#  'DescriptionEmb_502',
#  'DescriptionEmb_503',
#  'DescriptionEmb_504',
#  'DescriptionEmb_505',
#  'DescriptionEmb_506',
#  'DescriptionEmb_507',
#  'DescriptionEmb_508',
#  'DescriptionEmb_509',
#  'DescriptionEmb_510',
#  'DescriptionEmb_511',
#  'DescriptionEmb_512',
#  'DescriptionEmb_513',
#  'DescriptionEmb_514',
#  'DescriptionEmb_515',
#  'DescriptionEmb_516',
#  'DescriptionEmb_517',
#  'DescriptionEmb_518',
#  'DescriptionEmb_519',
#  'DescriptionEmb_520',
#  'DescriptionEmb_521',
#  'DescriptionEmb_522',
#  'DescriptionEmb_523',
#  'DescriptionEmb_524',
#  'DescriptionEmb_525',
#  'DescriptionEmb_526',
#  'DescriptionEmb_527',
#  'DescriptionEmb_528',
#  'DescriptionEmb_529',
#  'DescriptionEmb_530',
#  'DescriptionEmb_531',
#  'DescriptionEmb_532',
#  'DescriptionEmb_533',
#  'DescriptionEmb_534',
#  'DescriptionEmb_535',
#  'DescriptionEmb_536',
#  'DescriptionEmb_537',
#  'DescriptionEmb_538',
#  'DescriptionEmb_539',
#  'DescriptionEmb_540',
#  'DescriptionEmb_541',
#  'DescriptionEmb_542',
#  'DescriptionEmb_543',
#  'DescriptionEmb_544',
#  'DescriptionEmb_545',
#  'DescriptionEmb_546',
#  'DescriptionEmb_547',
#  'DescriptionEmb_548',
#  'DescriptionEmb_549',
#  'DescriptionEmb_550',
#  'DescriptionEmb_551',
#  'DescriptionEmb_552',
#  'DescriptionEmb_553',
#  'DescriptionEmb_554',
#  'DescriptionEmb_555',
#  'DescriptionEmb_556',
#  'DescriptionEmb_557',
#  'DescriptionEmb_558',
#  'DescriptionEmb_559',
#  'DescriptionEmb_560',
#  'DescriptionEmb_561',
#  'DescriptionEmb_562',
#  'DescriptionEmb_563',
#  'DescriptionEmb_564',
#  'DescriptionEmb_565',
#  'DescriptionEmb_566',
#  'DescriptionEmb_567',
#  'DescriptionEmb_568',
#  'DescriptionEmb_569',
#  'DescriptionEmb_570',
#  'DescriptionEmb_571',
#  'DescriptionEmb_572',
#  'DescriptionEmb_573',
#  'DescriptionEmb_574',
#  'DescriptionEmb_575',
#  'DescriptionEmb_576',
#  'DescriptionEmb_577',
#  'DescriptionEmb_578',
#  'DescriptionEmb_579',
#  'DescriptionEmb_580',
#  'DescriptionEmb_581',
#  'DescriptionEmb_582',
#  'DescriptionEmb_583',
#  'DescriptionEmb_584',
#  'DescriptionEmb_585',
#  'DescriptionEmb_586',
#  'DescriptionEmb_587',
#  'DescriptionEmb_588',
#  'DescriptionEmb_589',
#  'DescriptionEmb_590',
#  'DescriptionEmb_591',
#  'DescriptionEmb_592',
#  'DescriptionEmb_593',
#  'DescriptionEmb_594',
#  'DescriptionEmb_595',
#  'DescriptionEmb_596',
#  'DescriptionEmb_597',
#  'DescriptionEmb_598',
#  'DescriptionEmb_599',
#  'DescriptionEmb_600',
#  'DescriptionEmb_601',
#  'DescriptionEmb_602',
#  'DescriptionEmb_603',
#  'DescriptionEmb_604',
#  'DescriptionEmb_605',
#  'DescriptionEmb_606',
#  'DescriptionEmb_607',
#  'DescriptionEmb_608',
#  'DescriptionEmb_609',
#  'DescriptionEmb_610',
#  'DescriptionEmb_611',
#  'DescriptionEmb_612',
#  'DescriptionEmb_613',
#  'DescriptionEmb_614',
#  'DescriptionEmb_615',
#  'DescriptionEmb_616',
#  'DescriptionEmb_617',
#  'DescriptionEmb_618',
#  'DescriptionEmb_619',
#  'DescriptionEmb_620',
#  'DescriptionEmb_621',
#  'DescriptionEmb_622',
#  'DescriptionEmb_623',
#  'DescriptionEmb_624',
#  'DescriptionEmb_625',
#  'DescriptionEmb_626',
#  'DescriptionEmb_627',
#  'DescriptionEmb_628',
#  'DescriptionEmb_629',
#  'DescriptionEmb_630',
#  'DescriptionEmb_631',
#  'DescriptionEmb_632',
#  'DescriptionEmb_633',
#  'DescriptionEmb_634',
#  'DescriptionEmb_635',
#  'DescriptionEmb_636',
#  'DescriptionEmb_637',
#  'DescriptionEmb_638',
#  'DescriptionEmb_639',
#  'DescriptionEmb_640',
#  'DescriptionEmb_641',
#  'DescriptionEmb_642',
#  'DescriptionEmb_643',
#  'DescriptionEmb_644',
#  'DescriptionEmb_645',
#  'DescriptionEmb_646',
#  'DescriptionEmb_647',
#  'DescriptionEmb_648',
#  'DescriptionEmb_649',
#  'DescriptionEmb_650',
#  'DescriptionEmb_651',
#  'DescriptionEmb_652',
#  'DescriptionEmb_653',
#  'DescriptionEmb_654',
#  'DescriptionEmb_655',
#  'DescriptionEmb_656',
#  'DescriptionEmb_657',
#  'DescriptionEmb_658',
#  'DescriptionEmb_659',
#  'DescriptionEmb_660',
#  'DescriptionEmb_661',
#  'DescriptionEmb_662',
#  'DescriptionEmb_663',
#  'DescriptionEmb_664',
#  'DescriptionEmb_665',
#  'DescriptionEmb_666',
#  'DescriptionEmb_667',
#  'DescriptionEmb_668',
#  'DescriptionEmb_669',
#  'DescriptionEmb_670',
#  'DescriptionEmb_671',
#  'DescriptionEmb_672',
#  'DescriptionEmb_673',
#  'DescriptionEmb_674',
#  'DescriptionEmb_675',
#  'DescriptionEmb_676',
#  'DescriptionEmb_677',
#  'DescriptionEmb_678',
#  'DescriptionEmb_679',
#  'DescriptionEmb_680',
#  'DescriptionEmb_681',
#  'DescriptionEmb_682',
#  'DescriptionEmb_683',
#  'DescriptionEmb_684',
#  'DescriptionEmb_685',
#  'DescriptionEmb_686',
#  'DescriptionEmb_687',
#  'DescriptionEmb_688',
#  'DescriptionEmb_689',
#  'DescriptionEmb_690',
#  'DescriptionEmb_691',
#  'DescriptionEmb_692',
#  'DescriptionEmb_693',
#  'DescriptionEmb_694',
#  'DescriptionEmb_695',
#  'DescriptionEmb_696',
#  'DescriptionEmb_697',
#  'DescriptionEmb_698',
#  'DescriptionEmb_699',
#  'DescriptionEmb_700',
#  'DescriptionEmb_701',
#  'DescriptionEmb_702',
#  'DescriptionEmb_703',
#  'DescriptionEmb_704',
#  'DescriptionEmb_705',
#  'DescriptionEmb_706',
#  'DescriptionEmb_707',
#  'DescriptionEmb_708',
#  'DescriptionEmb_709',
#  'DescriptionEmb_710',
#  'DescriptionEmb_711',
#  'DescriptionEmb_712',
#  'DescriptionEmb_713',
#  'DescriptionEmb_714',
#  'DescriptionEmb_715',
#  'DescriptionEmb_716',
#  'DescriptionEmb_717',
#  'DescriptionEmb_718',
#  'DescriptionEmb_719',
#  'DescriptionEmb_720',
#  'DescriptionEmb_721',
#  'DescriptionEmb_722',
#  'DescriptionEmb_723',
#  'DescriptionEmb_724',
#  'DescriptionEmb_725',
#  'DescriptionEmb_726',
#  'DescriptionEmb_727',
#  'DescriptionEmb_728',
#  'DescriptionEmb_729',
#  'DescriptionEmb_730',
#  'DescriptionEmb_731',
#  'DescriptionEmb_732',
#  'DescriptionEmb_733',
#  'DescriptionEmb_734',
#  'DescriptionEmb_735',
#  'DescriptionEmb_736',
#  'DescriptionEmb_737',
#  'DescriptionEmb_738',
#  'DescriptionEmb_739',
#  'DescriptionEmb_740',
#  'DescriptionEmb_741',
#  'DescriptionEmb_742',
#  'DescriptionEmb_743',
#  'DescriptionEmb_744',
#  'DescriptionEmb_745',
#  'DescriptionEmb_746',
#  'DescriptionEmb_747',
#  'DescriptionEmb_748',
#  'DescriptionEmb_749',
#  'DescriptionEmb_750',
#  'DescriptionEmb_751',
#  'DescriptionEmb_752',
#  'DescriptionEmb_753',
#  'DescriptionEmb_754',
#  'DescriptionEmb_755',
#  'DescriptionEmb_756',
#  'DescriptionEmb_757',
#  'DescriptionEmb_758',
#  'DescriptionEmb_759',
#  'DescriptionEmb_760',
#  'DescriptionEmb_761',
#  'DescriptionEmb_762',
#  'DescriptionEmb_763',
#  'DescriptionEmb_764',
#  'DescriptionEmb_765',
#  'DescriptionEmb_766',
#  'DescriptionEmb_767',
#  'principal_maker_target_enc',
#  'principal_or_first_maker_target_enc',
#  'copyright_holder_target_enc',
#  'acquisition_method_target_enc',
#  'dating_period_target_enc']

# %%
# 学習直前でwandbにログイン、こうしないと頻繁にnotebookが落ちる
from use_wandb import use_wandb
use_wandb(params=cfg['params'], PROJECT_NAME=cfg['competition_name'], TRIAL_NAME=TRIAL_NAME)
# e99ecbcc2d9a775a09280213a06af1cf174d0fe0
# Out:
# wandb: Currently logged in as: sinchir0 (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">14_add_description_emb_multilingual</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sinchir0/atmacup10" target="_blank">https://wandb.ai/sinchir0/atmacup10</a><br/>
#                 Run page: <a href="https://wandb.ai/sinchir0/atmacup10/runs/l02fihid" target="_blank">https://wandb.ai/sinchir0/atmacup10/runs/l02fihid</a><br/>
#                 Run data is saved locally in <code>/Users/shinichiro.saito/atmacup/my_pipeline/experiments/notebook/wandb/run-20210308_005038-l02fihid</code><br/><br/>

# %%
from fe import target_encoding
from lgbm import LGBM

lgbm = LGBM(train=train,
  test=test,
  target='likes',
  use_col=use_col,
  cat_col=cat_col,
  cfg=cfg,
  OUTPUT_DIR=OUTPUT_DIR,
  DO_FIT=True,
  DO_SEED_AVE=False,
  DEBUG=False,
  is_target_log=True)

feature_importance_df, order = lgbm.feature_importance(PLOT=False)
# Out:
# --------------FOLDS : 0 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.19007	valid_1's rmse: 1.22393
# [200]	training's rmse: 1.03365	valid_1's rmse: 1.10896
# [300]	training's rmse: 0.968829	valid_1's rmse: 1.08107
# [400]	training's rmse: 0.924769	valid_1's rmse: 1.07006
# [500]	training's rmse: 0.889855	valid_1's rmse: 1.06383
# [600]	training's rmse: 0.860348	valid_1's rmse: 1.06007
# [700]	training's rmse: 0.8343	valid_1's rmse: 1.05711
# [800]	training's rmse: 0.811196	valid_1's rmse: 1.0548
# [900]	training's rmse: 0.790396	valid_1's rmse: 1.05305
# [1000]	training's rmse: 0.771173	valid_1's rmse: 1.05142
# [1100]	training's rmse: 0.753744	valid_1's rmse: 1.04904
# [1200]	training's rmse: 0.736991	valid_1's rmse: 1.04759
# [1300]	training's rmse: 0.721167	valid_1's rmse: 1.04595
# [1400]	training's rmse: 0.706341	valid_1's rmse: 1.04467
# [1500]	training's rmse: 0.692399	valid_1's rmse: 1.04342
# [1600]	training's rmse: 0.679335	valid_1's rmse: 1.04223
# [1700]	training's rmse: 0.666724	valid_1's rmse: 1.04125
# [1800]	training's rmse: 0.655006	valid_1's rmse: 1.04001
# [1900]	training's rmse: 0.643637	valid_1's rmse: 1.0389
# [2000]	training's rmse: 0.63275	valid_1's rmse: 1.038
# [2100]	training's rmse: 0.622616	valid_1's rmse: 1.03687
# [2200]	training's rmse: 0.612863	valid_1's rmse: 1.03638
# [2300]	training's rmse: 0.603817	valid_1's rmse: 1.03604
# [2400]	training's rmse: 0.594723	valid_1's rmse: 1.03521
# [2500]	training's rmse: 0.585949	valid_1's rmse: 1.03463
# [2600]	training's rmse: 0.577457	valid_1's rmse: 1.03411
# [2700]	training's rmse: 0.569358	valid_1's rmse: 1.03365
# [2800]	training's rmse: 0.561216	valid_1's rmse: 1.03317
# [2900]	training's rmse: 0.553671	valid_1's rmse: 1.03241
# [3000]	training's rmse: 0.546243	valid_1's rmse: 1.03225
# [3100]	training's rmse: 0.538596	valid_1's rmse: 1.03206
# [3200]	training's rmse: 0.531819	valid_1's rmse: 1.03191
# [3300]	training's rmse: 0.525	valid_1's rmse: 1.03144
# [3400]	training's rmse: 0.517893	valid_1's rmse: 1.03131
# [3500]	training's rmse: 0.511271	valid_1's rmse: 1.03123
# [3600]	training's rmse: 0.505152	valid_1's rmse: 1.03088
# [3700]	training's rmse: 0.498872	valid_1's rmse: 1.03068
# [3800]	training's rmse: 0.49298	valid_1's rmse: 1.03053
# [3900]	training's rmse: 0.487365	valid_1's rmse: 1.03057
# Early stopping, best iteration is:
# [3813]	training's rmse: 0.49231	valid_1's rmse: 1.03043
# Fold 0 rmsle: 1.0304
# --------------FOLDS : 1 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18493	valid_1's rmse: 1.22677
# [200]	training's rmse: 1.02699	valid_1's rmse: 1.12165
# [300]	training's rmse: 0.962842	valid_1's rmse: 1.09981
# [400]	training's rmse: 0.919664	valid_1's rmse: 1.08958
# [500]	training's rmse: 0.884827	valid_1's rmse: 1.08296
# [600]	training's rmse: 0.85475	valid_1's rmse: 1.07876
# [700]	training's rmse: 0.829298	valid_1's rmse: 1.07638
# [800]	training's rmse: 0.805967	valid_1's rmse: 1.07405
# [900]	training's rmse: 0.784989	valid_1's rmse: 1.07202
# [1000]	training's rmse: 0.765186	valid_1's rmse: 1.0704
# [1100]	training's rmse: 0.747374	valid_1's rmse: 1.06921
# [1200]	training's rmse: 0.730579	valid_1's rmse: 1.06785
# [1300]	training's rmse: 0.714999	valid_1's rmse: 1.06712
# [1400]	training's rmse: 0.700271	valid_1's rmse: 1.0662
# [1500]	training's rmse: 0.686315	valid_1's rmse: 1.06554
# [1600]	training's rmse: 0.673332	valid_1's rmse: 1.06392
# [1700]	training's rmse: 0.66078	valid_1's rmse: 1.06316
# [1800]	training's rmse: 0.648877	valid_1's rmse: 1.06251
# [1900]	training's rmse: 0.637371	valid_1's rmse: 1.06147
# [2000]	training's rmse: 0.625969	valid_1's rmse: 1.0604
# [2100]	training's rmse: 0.61586	valid_1's rmse: 1.06034
# [2200]	training's rmse: 0.606295	valid_1's rmse: 1.05997
# [2300]	training's rmse: 0.597062	valid_1's rmse: 1.05917
# [2400]	training's rmse: 0.587539	valid_1's rmse: 1.05885
# [2500]	training's rmse: 0.578697	valid_1's rmse: 1.05861
# [2600]	training's rmse: 0.569545	valid_1's rmse: 1.05813
# Early stopping, best iteration is:
# [2599]	training's rmse: 0.569663	valid_1's rmse: 1.05807
# Fold 1 rmsle: 1.0580
# --------------FOLDS : 2 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.19075	valid_1's rmse: 1.21727
# [200]	training's rmse: 1.03623	valid_1's rmse: 1.10652
# [300]	training's rmse: 0.973201	valid_1's rmse: 1.07888
# [400]	training's rmse: 0.92984	valid_1's rmse: 1.06599
# [500]	training's rmse: 0.895313	valid_1's rmse: 1.05819
# [600]	training's rmse: 0.865703	valid_1's rmse: 1.05339
# [700]	training's rmse: 0.83987	valid_1's rmse: 1.04938
# [800]	training's rmse: 0.816657	valid_1's rmse: 1.04623
# [900]	training's rmse: 0.79527	valid_1's rmse: 1.04314
# [1000]	training's rmse: 0.77547	valid_1's rmse: 1.0405
# [1100]	training's rmse: 0.757227	valid_1's rmse: 1.03834
# [1200]	training's rmse: 0.740272	valid_1's rmse: 1.03621
# [1300]	training's rmse: 0.724491	valid_1's rmse: 1.03487
# [1400]	training's rmse: 0.709767	valid_1's rmse: 1.03393
# [1500]	training's rmse: 0.695656	valid_1's rmse: 1.03295
# [1600]	training's rmse: 0.682256	valid_1's rmse: 1.03158
# [1700]	training's rmse: 0.669577	valid_1's rmse: 1.03043
# [1800]	training's rmse: 0.657469	valid_1's rmse: 1.02999
# [1900]	training's rmse: 0.646064	valid_1's rmse: 1.02892
# [2000]	training's rmse: 0.634503	valid_1's rmse: 1.02801
# [2100]	training's rmse: 0.624313	valid_1's rmse: 1.02735
# [2200]	training's rmse: 0.614131	valid_1's rmse: 1.02695
# [2300]	training's rmse: 0.604716	valid_1's rmse: 1.02666
# [2400]	training's rmse: 0.595493	valid_1's rmse: 1.02642
# [2500]	training's rmse: 0.5865	valid_1's rmse: 1.02621
# [2600]	training's rmse: 0.578116	valid_1's rmse: 1.02545
# [2700]	training's rmse: 0.569945	valid_1's rmse: 1.02561
# Early stopping, best iteration is:
# [2602]	training's rmse: 0.57797	valid_1's rmse: 1.02542
# Fold 2 rmsle: 1.0254
# --------------FOLDS : 3 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18654	valid_1's rmse: 1.2357
# [200]	training's rmse: 1.02929	valid_1's rmse: 1.13027
# [300]	training's rmse: 0.96465	valid_1's rmse: 1.10497
# [400]	training's rmse: 0.92025	valid_1's rmse: 1.09261
# [500]	training's rmse: 0.884291	valid_1's rmse: 1.0858
# [600]	training's rmse: 0.854421	valid_1's rmse: 1.08079
# [700]	training's rmse: 0.828041	valid_1's rmse: 1.07775
# [800]	training's rmse: 0.804339	valid_1's rmse: 1.07487
# [900]	training's rmse: 0.783079	valid_1's rmse: 1.07296
# [1000]	training's rmse: 0.7633	valid_1's rmse: 1.0715
# [1100]	training's rmse: 0.745136	valid_1's rmse: 1.06986
# [1200]	training's rmse: 0.728199	valid_1's rmse: 1.06835
# [1300]	training's rmse: 0.712124	valid_1's rmse: 1.06678
# [1400]	training's rmse: 0.697441	valid_1's rmse: 1.06547
# [1500]	training's rmse: 0.683573	valid_1's rmse: 1.06456
# [1600]	training's rmse: 0.670192	valid_1's rmse: 1.06407
# [1700]	training's rmse: 0.657765	valid_1's rmse: 1.06338
# [1800]	training's rmse: 0.645453	valid_1's rmse: 1.06229
# [1900]	training's rmse: 0.633955	valid_1's rmse: 1.06165
# [2000]	training's rmse: 0.622981	valid_1's rmse: 1.06101
# [2100]	training's rmse: 0.612846	valid_1's rmse: 1.06081
# Early stopping, best iteration is:
# [2060]	training's rmse: 0.61672	valid_1's rmse: 1.0605
# Fold 3 rmsle: 1.0605
# --------------FOLDS : 4 --------------
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:151: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/engine.py:156: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['acquisition_method', 'art_series_id', 'copyright_holder', 'principal_maker', 'principal_or_first_maker']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18925	valid_1's rmse: 1.2358
# [200]	training's rmse: 1.03438	valid_1's rmse: 1.11641
# [300]	training's rmse: 0.970133	valid_1's rmse: 1.08643
# [400]	training's rmse: 0.925983	valid_1's rmse: 1.07355
# [500]	training's rmse: 0.8913	valid_1's rmse: 1.0653
# [600]	training's rmse: 0.860896	valid_1's rmse: 1.05955
# [700]	training's rmse: 0.835049	valid_1's rmse: 1.05517
# [800]	training's rmse: 0.81154	valid_1's rmse: 1.05184
# [900]	training's rmse: 0.790037	valid_1's rmse: 1.04941
# [1000]	training's rmse: 0.770475	valid_1's rmse: 1.04739
# [1100]	training's rmse: 0.752523	valid_1's rmse: 1.04514
# [1200]	training's rmse: 0.735825	valid_1's rmse: 1.04354
# [1300]	training's rmse: 0.719865	valid_1's rmse: 1.04156
# [1400]	training's rmse: 0.705349	valid_1's rmse: 1.04052
# [1500]	training's rmse: 0.691095	valid_1's rmse: 1.04015
# [1600]	training's rmse: 0.677869	valid_1's rmse: 1.03933
# [1700]	training's rmse: 0.665495	valid_1's rmse: 1.03839
# [1800]	training's rmse: 0.653487	valid_1's rmse: 1.03742
# [1900]	training's rmse: 0.642345	valid_1's rmse: 1.03686
# [2000]	training's rmse: 0.631753	valid_1's rmse: 1.0364
# [2100]	training's rmse: 0.62144	valid_1's rmse: 1.03616
# [2200]	training's rmse: 0.611545	valid_1's rmse: 1.03547
# [2300]	training's rmse: 0.601962	valid_1's rmse: 1.03508
# Early stopping, best iteration is:
# [2298]	training's rmse: 0.60214	valid_1's rmse: 1.03507
# Fold 4 rmsle: 1.0351
# ALL likes rmsle:  1.0420

# %%
os.makedirs(f"{OUTPUT_DIR}/imp", exist_ok=True)
feature_importance_df[order[:50]].to_csv(f"{OUTPUT_DIR}/imp/importance.csv")
display(feature_importance_df[order[:50]])
# Out:
#            subtitle_h           area     subtitle_w  principal_maker  \
# fold_0  329430.218608   50754.350918  164302.817583     42013.629763
# fold_1  354184.179116   66145.159881  113359.247456     34765.020424
# fold_2  330192.659541   51059.006196  154691.127203     34658.302901
# fold_3  317226.171323   84340.560649  132277.828041     34512.090289
# fold_4  362625.381223  117643.215128   51692.353389     37130.672277
#
#         principal_maker_target_enc  principal_or_first_maker_target_enc  \
# fold_0                37277.058943                         29727.915898
# fold_1                37228.307082                         30976.070367
# fold_2                36166.907046                         34002.514017
# fold_3                36685.035530                         29091.446723
# fold_4                35261.697354                         28047.099086
#
#         principal_or_first_maker  dating_year_early  StringLength__more_title  \
# fold_0              28232.555321       15978.220185              14668.947873
# fold_1              29621.854257       16006.855176              15593.559167
# fold_2              29460.307957       15162.375805              13479.053898
# fold_3              28015.014863       13033.126571              11730.847611
# fold_4              27900.783740       16027.904612              13199.157262
#
#         dating_year_late  ...  DescriptionEmb_72  DescriptionEmb_697  \
# fold_0      13332.428277  ...        1357.454949          587.311806
# fold_1      11573.349403  ...         679.134359          597.432356
# fold_2      11303.669253  ...         619.129919          513.383912
# fold_3      10001.906894  ...         935.186290          573.644040
# fold_4      10157.814543  ...        1115.374454         1111.290328
#
#         AcquisitionDate_dayofweek  DescriptionEmb_490  DescriptionEmb_192  \
# fold_0                1274.345728         1057.155164          726.898559
# fold_1                 929.948846         1059.251467          702.258470
# fold_2                1134.669788         1095.947590          603.307788
# fold_3                 847.473070          914.007806          791.741320
# fold_4                1105.490950         1098.282001         1078.442526
#
#         DescriptionEmb_60  DescriptionEmb_471  DescriptionEmb_208  \
# fold_0         596.585379         1896.693161          572.303751
# fold_1         661.934957         1096.581161          672.161758
# fold_2         621.717103         1755.661780          728.273301
# fold_3         848.613735         1071.655659          412.086487
# fold_4        1075.418634         1073.261240         1069.305810
#
#         DescriptionEmb_181  DescriptionEmb_159
# fold_0         1405.908118         1334.314401
# fold_1          752.763626          939.446691
# fold_2         1259.120988         1753.429493
# fold_3         1040.354231          692.474479
# fold_4         1052.764123         1046.642517
#
# [5 rows x 50 columns]

# %%
from make_data import make_oof
oof_df = make_oof(OUTPUT_DIR=OUTPUT_DIR, TARGET=cfg['target'])

# %%
# from score import calc_macro_auc
# score = calc_macro_auc(train_target_df=train_target_df, oof_df=oof_df, order_list=TARGET_IDS)

# %%
sample_sub = pd.read_csv('../../data/atmacup10__sample_submission.csv')

# %%
from make_data import make_sub
sub_df = make_sub(sample_sub=sample_sub, TARGET_NAME=cfg['target'], TRIAL_NAME=TRIAL_NAME, OUTPUT_DIR=OUTPUT_DIR, cv_score=lgbm.score)
# Out:
# QUick Sub
# sh sub.sh output/20210308005033_14_add_description_emb_multilingual/pred/pred_likes_1.0420.csv

# %%
sub_df.describe()
# Out:
#               likes
# count  12008.000000
# mean      21.806271
# std       70.815752
# min        0.000000
# 25%        0.936886
# 50%        2.354351
# 75%        6.675263
# max     1918.870234

# %%
from make_fig import make_dist_oof_pred
make_dist_oof_pred(oof_df=oof_df,sub_df=sub_df,OUTPUT_DIR=OUTPUT_DIR)
