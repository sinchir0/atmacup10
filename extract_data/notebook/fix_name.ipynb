# %%
import pandas as pd
import numpy as np

from pathlib import Path

from gensim.models import word2vec, KeyedVectors
from tqdm import tqdm
tqdm.pandas()
# Out:
# /Users/shinichiro.saito/opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
sub = pd.read_csv('../../data/atmacup10__sample_submission.csv')
color = pd.read_csv('../../data/color.csv')
historical_person = pd.read_csv('../../data/historical_person.csv')
maker = pd.read_csv('../../data/maker.csv')
material = pd.read_csv('../../data/material.csv')
collection = pd.read_csv('../../data/object_collection.csv')
palette = pd.read_csv('../../data/palette.csv')
principal_maker_occupation = pd.read_csv('../../data/principal_maker_occupation.csv')
principal_maker = pd.read_csv('../../data/principal_maker.csv')
production_place = pd.read_csv('../../data/production_place.csv')
technique = pd.read_csv('../../data/technique.csv')
test = pd.read_csv('../../data/test.csv')
train = pd.read_csv('../../data/train.csv')

# %%
from geopy.geocoders import Nominatim
import numpy as np

def place2country(address):
    geolocator = Nominatim(user_agent='sample', timeout=200)
    loc = geolocator.geocode(address, language='en')
    coordinates = (loc.latitude, loc.longitude)
    location = geolocator.reverse(coordinates, language='en')
    country = location.raw['address']['country']
    return country

# %%
from tqdm import tqdm_notebook as tqdm

place_list = production_place['name'].unique()
country_dict = {}
for place in tqdm(place_list):
    if place != place:
        continue
    try:
        country = place2country(place)
        country_dict[place] = country
    except:
        # 国名を取得できない場合はnan
        print(place)
        country_dict[place] = np.nan
# Out:
# <ipython-input-4-25aa529dbafa>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for place in tqdm(place_list):
# ...
# Indonesian Archipelago

# %%
production_place['country_name'] = production_place['name'].map(country_dict)
production_place.head()
# Out:
#               object_id                  name country_name
# 0  0012765f7a97ccc3e9e9           Netherlands  Netherlands
# 1  00133be3ff222c9b74b0             Amsterdam  Netherlands
# 2  00133be3ff222c9b74b0  Northern Netherlands  Netherlands
# 3  0017be8caa87206532cb             Amsterdam  Netherlands
# 4  001b2b8c9d3aa1534dfe              Suriname     Suriname

# %%
production_place.to_csv('../production_place_rename.csv')

# %%
from tqdm import tqdm_notebook as tqdm

place_of_birth_list = maker['place_of_birth'].unique()
country_dict = {}
for place in tqdm(place_of_birth_list):
    if place != place:
        continue
    try:
        country = place2country(place)
        country_dict[place] = country
    except:
        # 国名を取得できない場合はnan
        print(place)
        country_dict[place] = np.nan
# Out:
# <ipython-input-15-5126e935f6a8>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for place in tqdm(place_of_birth_list):
# ...
# Kralingen-Ambacht
# Brembate Superiore
# Rio Demerary
# Monte Scùdolo
# Fuentedetodos
# Baierrain
# Zwollerkerspel
# Wehlerad
# Kalimaro (Ned.Indië)
# Honjo Warigesui
# Théâtre des Folies-Marigny
# Goëngamieden

# %%
country_dict
# Out:
# {"'s-Heerenberg": 'Netherlands',
#  'Amsterdam': 'Netherlands',
#  'Utrecht': 'Netherlands',
#  'Gorinchem': 'Netherlands',
#  'Antwerpen': 'Belgium',
#  'Rotterdam': 'Netherlands',
#  'Leiden': 'Netherlands',
#  'Den Haag': 'Netherlands',
#  'Delft': 'Netherlands',
#  'Frankfurt am Main': 'Germany',
#  'Lisse': 'Netherlands',
#  'Groningen': 'Netherlands',
#  'Dordrecht': 'Netherlands',
#  'Haarlem': 'Netherlands',
#  'Leeuwarden': 'Netherlands',
#  'Parijs': 'France',
#  'Brussel': 'Belgium',
#  'Schiedam': 'Netherlands',
#  'Londen': 'United Kingdom',
#  'Wenen': 'Austria',
#  'Kortrijk': 'Belgium',
#  'Mandal': 'Mongolia',
#  'Sainte-Croix': 'France',
#  'Marseille': 'France',
#  'Tilburg': 'Netherlands',
#  'Oudenaarde': 'Belgium',
#  'Schagen': 'Netherlands',
#  'Rijswijk': 'Netherlands',
#  'Kralingen-Ambacht': nan,
#  'Ouderkerk aan de Amstel': 'Netherlands',
#  'Zaltbommel': 'Netherlands',
#  'Florence': 'Italy',
#  'Bologna': 'Italy',
#  'Battedizzo': 'Italy',
# ...

# %%
maker['place_of_birth_country_name'] = maker['place_of_birth'].map(country_dict)
maker.head()
# Out:
#                 name place_of_birth date_of_birth date_of_death  \
# 0           't Hooft            NaN           NaN           NaN
# 1     A. & G. Taylor            NaN           NaN           NaN
# 2        A. Böeseken  's-Heerenberg    1834-01-12    1919-02-11
# 3  A. Cucumus & Cie.            NaN           NaN           NaN
# 4          A. Dandoy            NaN           NaN           NaN
#
#   place_of_death nationality place_of_birth_country_name
# 0            NaN         NaN                         NaN
# 1            NaN         NaN                         NaN
# 2      Rotterdam         NaN                 Netherlands
# 3            NaN         NaN                         NaN
# 4            NaN         NaN                         NaN

# %%
from tqdm import tqdm_notebook as tqdm

place_of_death_list = maker['place_of_death'].unique()
country_dict = {}
for place in tqdm(place_of_death_list):
    if place != place:
        continue
    try:
        country = place2country(place)
        country_dict[place] = country
    except:
        # 国名を取得できない場合はnan
        print(place)
        country_dict[place] = np.nan
        
maker['place_of_death_country_name'] = maker['place_of_death'].map(country_dict)
maker.head()
# Out:
# <ipython-input-18-23a7f0d61791>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for place in tqdm(place_of_death_list):
# ...
# Théâtre des Folies-Marigny
# Bieberich
#                 name place_of_birth date_of_birth date_of_death  \
# 0           't Hooft            NaN           NaN           NaN
# 1     A. & G. Taylor            NaN           NaN           NaN
# 2        A. Böeseken  's-Heerenberg    1834-01-12    1919-02-11
# 3  A. Cucumus & Cie.            NaN           NaN           NaN
# 4          A. Dandoy            NaN           NaN           NaN
#
#   place_of_death nationality place_of_birth_country_name  \
# 0            NaN         NaN                         NaN
# 1            NaN         NaN                         NaN
# 2      Rotterdam         NaN                 Netherlands
# 3            NaN         NaN                         NaN
# ...

# %%
maker.to_csv('../maker_rename.csv')
